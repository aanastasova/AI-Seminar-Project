# %% [markdown]
# # Lecture 3 - Topic Modeling with Latent Dirichlet Allocation
# * Text Retrieval and Mining, BSc BAN, 2023-2024
# * Author: [Julien Rossi](mailto:j.rossi@uva.nl)

# %% [markdown]
# ## External Resources

# %% [markdown]
# * [Youtube Video by Luis Serrano](https://www.youtube.com/watch?v=T05t-SqKArY)
# * [Illustrated Mechanism by Arun K Sharma](https://www.mygreatlearning.com/blog/understanding-latent-dirichlet-allocation/)
# * [Blog Post by Thushan Ganegedara](https://towardsdatascience.com/light-on-math-machine-learning-intuitive-guide-to-latent-dirichlet-allocation-437c81220158)
# * [Blog Post by Ria Kulshrestha](https://towardsdatascience.com/latent-dirichlet-allocation-lda-9d1cd064ffa2)
# * [Blog Post by Shashank Kapadia about Evaluation of LDA](https://towardsdatascience.com/evaluate-topic-model-in-python-latent-dirichlet-allocation-lda-7d57484bb5d0)

# %% [markdown]
# ## Problem Statement
#
# Following the introduction of LDA:
# * Concept of a document made of topics = a Bag of Words made of topics
# * Concept of a topic made of words

# %% [markdown]
# # Example: Health in Vogue Magazine

# %% [markdown]
# Let's have a look at [this study by Peter Leonard](http://library.ifla.org/930/1/119-leonard-en.pdf) about the Vogue dataset.
#
# [Vogue Magazine](https://en.wikipedia.org/wiki/Vogue_(magazine) is a women's fashion and lifestyle magazine, launched in 1916:
# * Over 100,000 articles
# * More than 400,000 pages
#
# We are looking at answering 2 questions:
# * What is the importance of Health in Vogue across time? What proportion of articles deal with Health in publications?
# * How does Vogue deal with Health?
#
#
#
# ---
#
#
#
# This graph shows the percentage of articles that dedicate significant room to discuss health-related topics, across time and annotated for Editor-in-Chief:
#
# ![image](https://i.ibb.co/1mf9YKq/Screenshot-from-2020-12-11-16-53-42.png)
#
#
#
#
# ---
#
# This cloud of words shows which terms are mainly used to talk about health:
#
# ![image](https://i.ibb.co/ZgXqSDQ/Screenshot-from-2020-12-11-17-04-46.png)
#
#
#
# ---
#
# As an addition, a TOP-7 articles that talk the most about Health. The percentage indicates how much of the article is dedicated to Health.
#
# * `99%` “Q&A: The Pill” 1 Dec. 1987: 361
# * `98%` Jane Ogle. “Facts on Fat: Obesity — a Heavy Health-risk Factor” 1 Aug. 1979: 249
# * `96%` Melva Weber. “Inner Info: Contraception” 1 Aug. 1978: 210
# * `95%` Charles Kuntzleman. “What Is the Best Way That You Can Shape Up for Active Sports?” 1 Aug. 1979: 82
# * `95%` Jane Ogle. “Why Crash Diets Don't Work” 1 Aug. 1979: 248
# * `91%` Melva Weber. “Latest in the IUD Dust-Up...” 1 Mar. 1975: 88
# * `89%` Ellen Switzer. “Your Blood Pressure” 1 May. 1973: 152

# %% [markdown]
# **How can you do that, without reading and annotating each and every article ?**
# Answer: Topic Modeling, with Latent Dirichlet Allocation

# %% [markdown]
# ## Intuition
#
# LDA is a **generative** model
# * Each **Topic** is a probability distribution over a collection of words
#    * Each word has a probability
#    * The sum of all probabilities is equal to $1$
# * Each **Document** (each BoW) is a sample of a random process, it is generated by a probability distribution over a list of topics
#    * Each document is a weighted sum of topics
#    * The sum of all weights is equal to $1$
#
# The generative model runs like this:
# * Given a document, the distribution of topics is a sample from a Dirichlet distribution
#    * Each sample is a vector $\textrm{v}$ of dimension $K$ the number of topics
#    * $\textrm{v} = (\textrm{v}_1, \textrm{v}_2, ..., \textrm{v}_K)$
#    * $\textrm{v}_i \geq 0$
#    * $\sum_{i=1}^K \textrm{v}_i = 1$
# * The words of the document come from a random draw from the topics's word distribution
#    * As different weights have been assigned to different topics, some topics will generate more words than others
#    * As words in a topic do not all have the same probability, it is more likely to see some of them than the others
#
# With the help of Machine Learning, we discover the parameters of these distributions from the corpus of text at disposal, and can represent each document as a vector of dimension $K$.
#
# We observe the words with highest probability of each topic and label the topics manually for our understanding.

# %% [markdown]
# ## Examples

# %% [markdown]
# We have 2 topics: `Sports` and `Business`.
# * `Sports`: `football: 0.4`, `ronaldo: 0.2`, `goal: 0.2`, `worldcup: 0.2`
# * `Business`: `revenue: 0.6`, `tax: 0.3`, `benefit: 0.1`
#
# A document which is split:
# * `Sports: 0.8`
# * `Business: 0.2`
#
# We build the bag of words the following way:
# * 80% of the time, we draw a word from the `Sports` distribution.
# * 20% of the time, a word from `Business`
#
# For a 5-word bag of words, we obtain:
# * 4 words from `Sports`: `football: 1`, `ronaldo: 1`, `goal: 2`
# * 1 word from `Business`: `revenue: 1`
#
# This bag of words is valid for a document like `Football star Ronaldo's revenue grows as he scores goal after goal`.
#
# (admitting `grow` and `star` would be stop-words, but it's a toy example, we can allow this).

# %% [markdown]
# ## Explain the Vogue Research

# %% [markdown]
# * This was a LDA modeling with $K=20$ topics
# * Topic #14 was labeled as Health
# * The graph shows the number of articles where the 14th coefficient of the LDA vector is higher than $0.2$, as a percentage of the total number of articles published in a year.

# %% [markdown]
# # Application

# %% [markdown]
# We will use a dataset of BBC articles, see the [BBC Page](http://mlg.ucd.ie/datasets/bbc.html)
#
# We use gensim implementation of LDA. See [Link](https://radimrehurek.com/gensim/auto_examples/tutorials/run_lda.html)

# %%
# Activate or deactivate logging by changing False into True
# Gensim can be very verbose !!!

if True:
    import logging
    logging.basicConfig(format="%(asctime)s:%(name)s:%(levelname)s:%(message)s",
                        level=logging.INFO)

import os
os.environ["FORCE_COLOR"] = "1"

# %% [markdown]
# ## Prepare Corpus

# %%
import requests

r = requests.get('http://mlg.ucd.ie/files/datasets/bbc-fulltext.zip')

assert r.status_code == 200

with open('bbc-fulltext.zip', 'wb') as out:
    out.write(r.content)

# %%
from zipfile import ZipFile

texts = []
with ZipFile('bbc-fulltext.zip') as zf:
    txtfiles = filter(lambda x: x.endswith('.txt'), zf.namelist())
    for txtf in txtfiles:
        with zf.open(txtf, 'r') as txt:
            texts.append(txt.read().decode('utf-8', 'ignore').lower().replace('\n', ' '))

print(f'Collected {len(texts)} articles.')
# Out:
# Collected 2225 articles.

# %%
texts[0]
# Out:
# 'musicians to tackle us red tape  musicians\' groups are to tackle us visa regulations which are blamed for hindering british acts\' chances of succeeding across the atlantic.  a singer hoping to perform in the us can expect to pay $1,300 (£680) simply for obtaining a visa. groups including the musicians\' union are calling for an end to the "raw deal" faced by british performers. us acts are not faced with comparable expense and bureaucracy when visiting the uk for promotional purposes.  nigel mccune from the musicians\' union said british musicians are "disadvantaged" compared to their us counterparts. a sponsor has to make a petition on their behalf, which is a form amounting to nearly 30 pages, while musicians face tougher regulations than athletes and journalists. "if you make a mistake on your form, you risk a five-year ban and thus the ability to further your career," says mr mccune.  "the us is the world\'s biggest music market, which means something has to be done about the creaky bureaucracy," says mr mccune. "the current situation is preventing british acts from maintaining momentum and developing in the us," he added.  the musicians\' union stance is being endorsed by the music managers\' forum (mmf), who say british artists face "an uphill struggle" to succeed in the us, thanks to the tough visa requirements, which are also seen as impractical. the mmf\'s general secretary james seller said: "imagine if you were an orchestra from the orkneys? every member would have to travel to london to have their visas processed."  "the us market is seen as the holy grail and one of the benchmarks of success, and we\'re still going to fight to get in there. "it\'s still very important, but there are other markets like europe, india and china," added mr seller. a department for media, culture and sport spokeswoman said: "we\'re aware that people are experiencing problems, and are working with the us embassy and record industry to see what we can do about it." a us embassy spokesman said: "we are aware that entertainers require visas for time-specific visas and are doing everything we can to process those applications speedily." "we are aware of the importance of cultural exchange and we will do our best to facilitate that," he added. '

# %% [markdown]
# We will build the vocabulary as follows:
# * We want 1-grams and 2-grams
# * Tokenize the text with `spacy`, create 2 versions
#    * One with each token
#    * Another one where stopwords are removed
# * Use `gensim` Phrases to generate 2-grams
#    * It uses the full tokenized version of the corpus
#    * It names bigrams as `after_hour`, and identifies more complex structures, such as `king_of_heart` which is a 2-gram when discounting the stopword `of` which is only a connector here
# * After the 2-grams are generated, we add them to the 'tokenized and stopped' corpus
#    * LDA is a generative model for the Bag of Words
#    * Composition does not matter
#    * What matters is that the right list of terms and counts is provided

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

full_tokenized = list(map(
    lambda tokens: [t.text for t in tokens if len(t.text) > 1],
    nlp.tokenizer.pipe(texts)  # [['I', 'Love', 'tea'], ['I', 'teach', 'at', 'uva']]
))

add_stops = ['said', 'mr']

def filter_tokens(x):
    return [t.text for t in x if len(t.text) > 1 and not t.is_stop and t.text not in add_stops]

stopped_tokenized = list(map(
    filter_tokens,
    nlp.tokenizer.pipe(texts) # [['I', 'Love', 'tea'], ['I', 'teach', 'at', 'uva']]
))

# %%
import warnings

from gensim.corpora.dictionary import Dictionary
from gensim.models.phrases import Phrases

warnings.filterwarnings("ignore", category=DeprecationWarning)

# Add bigrams to docs (only ones that appear 10 times or more).
bigram = Phrases(full_tokenized, min_count=10)
for idx in range(len(full_tokenized)):
    for token in bigram[full_tokenized[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            stopped_tokenized[idx].append(token)

dictionary = Dictionary(stopped_tokenized)

# Filter out words that occur less than 10 documents, or more than 90% of the documents.
# Same effect as min_df, max_df in CountVectorizer
dictionary.filter_extremes(no_below=5, no_above=0.9)
dictionary.compactify()

corpus = [dictionary.doc2bow(txt) for txt in stopped_tokenized]

# %%
len(dictionary)
# Out:
# 10494

# %%
list([(i, dictionary[i]) for i in range(20)])
# Out:
# [(0, "'s_biggest"),
#  (1, '30'),
#  (2, 'ability'),
#  (3, 'acts'),
#  (4, 'added'),
#  (5, 'amounting'),
#  (6, 'applications'),
#  (7, 'artists'),
#  (8, 'athletes'),
#  (9, 'atlantic'),
#  (10, 'aware'),
#  (11, 'ban'),
#  (12, 'behalf'),
#  (13, 'best'),
#  (14, 'biggest'),
#  (15, 'blamed'),
#  (16, 'british'),
#  (17, 'bureaucracy'),
#  (18, 'calling'),
#  (19, 'career')]

# %% [markdown]
# ## LDA Model

# %% [markdown]
# The number of topics is a Hyperparameter of our model.
#
# In evaluation, we will be able to see what would be a *better* choice for the number of topics.

# %%
K = 10

# %%
from gensim.models.ldamodel import LdaModel

lda = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=K,
    alpha='auto',
    eta='auto',
    iterations=100,
    passes=20,
    eval_every=None,
    random_state=42,
    per_word_topics=True
)

# %% [markdown]
# ## Annotation

# %% [markdown]
# ### View Topics

# %% [markdown]
# We have a look at each topic, and the corresponding list of words.
#
# * Each topic is a probability distribution over the vocabulary
# * Each word has a probability between 0 and 1
# * Words with high probabilities indicate important words for the topic
# * We focus on the TOP 10 words to annotate and give a title to a topic

# %%
lda.print_topics()
# Out:
# [(0,
#   '0.009*"world" + 0.007*"music" + 0.007*"new" + 0.007*"says" + 0.007*"people" + 0.007*"internet" + 0.006*"software" + 0.005*"project" + 0.005*"computer" + 0.005*"service"'),
#  (1,
#   '0.010*"games" + 0.009*"music" + 0.008*"technology" + 0.007*"digital" + 0.007*"sony" + 0.007*"will_be" + 0.006*"new" + 0.006*"video" + 0.006*"people" + 0.006*"mobile"'),
#  (2,
#   '0.013*"software" + 0.011*"security" + 0.010*"microsoft" + 0.009*"users" + 0.008*"people" + 0.008*"virus" + 0.008*"system" + 0.007*"windows" + 0.007*"new" + 0.006*"mail"'),
#  (3,
#   '0.010*"year" + 0.008*"company" + 0.007*"sales" + 0.005*"market" + 0.005*"firm" + 0.004*"oil" + 0.004*"2004" + 0.004*"deal" + 0.004*"bank" + 0.004*"shares"'),
#  (4,
#   '0.012*"china" + 0.008*"year" + 0.008*"world" + 0.007*"new" + 0.006*"growth" + 0.005*"uk" + 0.005*"game" + 0.005*"years" + 0.004*"people" + 0.004*"economy"'),
#  (5,
#   '0.016*"search" + 0.013*"people" + 0.010*"information" + 0.009*"site" + 0.008*"google" + 0.008*"online" + 0.006*"users" + 0.006*"web" + 0.005*"use" + 0.005*"yahoo"'),
#  (6,
#   '0.009*"government" + 0.006*"labour" + 0.006*"people" + 0.005*"he_said" + 0.005*"election" + 0.005*"minister" + 0.005*"party" + 0.004*"blair" + 0.004*"new" + 0.004*"told"'),
#  (7,
#   '0.020*"mobile" + 0.014*"phone" + 0.014*"people" + 0.011*"broadband" + 0.010*"uk" + 0.009*"services" + 0.008*"phones" + 0.007*"net" + 0.007*"service" + 0.006*"million"'),
#  (8,
#   '0.019*"film" + 0.015*"best" + 0.010*"game" + 0.010*"awards" + 0.009*"mac" + 0.008*"life" + 0.007*"apple" + 0.007*"award" + 0.007*"players" + 0.006*"won"'),
#  (9,
#   '0.006*"year" + 0.006*"game" + 0.006*"time" + 0.005*"world" + 0.004*"win" + 0.004*"england" + 0.004*"new" + 0.004*"best" + 0.003*"play" + 0.003*"second"')]

# %% [markdown]
# This is one case where wordclouds come in handy.

# %%
import math
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS

nb_columns = 5
nb_rows = math.ceil(K / nb_columns)

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'
cols = cols * math.ceil(K / len(cols))

cloud = WordCloud(background_color='white',
                  width=400,
                  height=400,
                  max_words=10,
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda.show_topics(num_topics=K, num_words=10, formatted=False)

fig, axes = plt.subplots(ncols=nb_columns, nrows=nb_rows,
                         figsize=(4*nb_columns, 4*nb_rows),
                         sharex=True, sharey=True)

for i, (topic, ax) in enumerate(zip(topics, axes.flatten())):
    topic_words = dict(topic[1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    ax.imshow(cloud)
    ax.set_title('Topic ' + str(i), fontdict=dict(size=16))
    ax.axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Label the Topics

# %% [markdown]
# We can label the topics
# * Observing the collection of most frequent words
# * It is a **Human Annotation** task
# * Use world knowledge, domain knowledge, historical trends and zeitgeist
# * Some subjectivity...

# %%
topic_names = {i: f"#{i:02d}" for i in range(10)}

# %% [markdown]
# ### Get Topic Distribution for Documents

# %% [markdown]
# We get the vectors for some documents by providing a corpus
# * Either `lda.get_document_topics(doc)` which take 1 corpus's document at a time
# * Or `lda[corpus]` which processes the whole corpus at once

# %%
by_get_document_topics = list(map(
    lda.get_document_topics,
    corpus
))

by_bracket = lda[corpus]

# %%
from textwrap import fill

print(fill(texts[0], width=80))
# Out:
# musicians to tackle us red tape  musicians' groups are to tackle us visa
# regulations which are blamed for hindering british acts' chances of succeeding
# across the atlantic.  a singer hoping to perform in the us can expect to pay
# $1,300 (£680) simply for obtaining a visa. groups including the musicians' union
# are calling for an end to the "raw deal" faced by british performers. us acts
# are not faced with comparable expense and bureaucracy when visiting the uk for
# promotional purposes.  nigel mccune from the musicians' union said british
# musicians are "disadvantaged" compared to their us counterparts. a sponsor has
# to make a petition on their behalf, which is a form amounting to nearly 30
# pages, while musicians face tougher regulations than athletes and journalists.
# "if you make a mistake on your form, you risk a five-year ban and thus the
# ability to further your career," says mr mccune.  "the us is the world's biggest
# music market, which means something has to be done about the creaky
# bureaucracy," says mr mccune. "the current situation is preventing british acts
# from maintaining momentum and developing in the us," he added.  the musicians'
# union stance is being endorsed by the music managers' forum (mmf), who say
# british artists face "an uphill struggle" to succeed in the us, thanks to the
# tough visa requirements, which are also seen as impractical. the mmf's general
# secretary james seller said: "imagine if you were an orchestra from the orkneys?
# every member would have to travel to london to have their visas processed."
# "the us market is seen as the holy grail and one of the benchmarks of success,
# and we're still going to fight to get in there. "it's still very important, but
# there are other markets like europe, india and china," added mr seller. a
# department for media, culture and sport spokeswoman said: "we're aware that
# people are experiencing problems, and are working with the us embassy and record
# industry to see what we can do about it." a us embassy spokesman said: "we are
# aware that entertainers require visas for time-specific visas and are doing
# everything we can to process those applications speedily." "we are aware of the
# importance of cultural exchange and we will do our best to facilitate that," he
# added.

# %% [markdown]
# * Not exactly the same structure (more info returned by `[]`)
# * Some small numerical differences, but insignificant
# * Return the list of TOP topics, and set to 0 all those who had a very low value

# %%
print(f'Using get_document_topics: {by_get_document_topics[0]}')
print(f'Using square brackets    : {by_bracket[0][0]}')
# Out:
# Using get_document_topics: [(0, 0.23726887), (3, 0.09250132), (4, 0.03216001), (5, 0.033605296), (6, 0.54278755), (9, 0.060357325)]
# Using square brackets    : [(0, 0.23726694), (3, 0.09249788), (4, 0.032166027), (5, 0.033605304), (6, 0.5427767), (9, 0.060367502)]

# %%
for topic_id, value in by_get_document_topics[0]:
    print(f'Topic #{topic_id:2d} ({topic_names[topic_id]:<20}): {value:>4.3f}')
print('-' * 40)
print(f'Sum {sum(x[1] for x in by_get_document_topics[0]):>35.3f}')
# Out:
# Topic # 0 (#00                 ): 0.237
# Topic # 3 (#03                 ): 0.093
# Topic # 4 (#04                 ): 0.032
# Topic # 5 (#05                 ): 0.034
# Topic # 6 (#06                 ): 0.543
# Topic # 9 (#09                 ): 0.060
# ----------------------------------------
# Sum                               0.999

# %%
import rich

from rich.console import Console
from rich.table import Table

table = Table(title=f"Topics in Document")

table.add_column("Topic ID", justify="left", style="black")
table.add_column("Topic Name", justify="left")
table.add_column("Topic Weight", justify="right")

for topic_id, value in by_get_document_topics[0]:
    table.add_row(f"{topic_id:02d}", f"{topic_names[topic_id]:<20}", f"{value:>4.3f}")

console = Console(record=True, width=60)
console.print(table, justify="center")
console.save_svg("lda.svg", title="Topics in Document")
# Out:
#                      Topics in Document
#      ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
#      ┃ Topic ID ┃ Topic Name           ┃ Topic Weight ┃
#      ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
#      │ 00       │ #00                  │        0.237 │
#      │ 03       │ #03                  │        0.093 │
#      │ 04       │ #04                  │        0.032 │
#      │ 05       │ #05                  │        0.034 │
#      │ 06       │ #06                  │        0.543 │
#      │ 09       │ #09                  │        0.060 │
#      └──────────┴──────────────────────┴──────────────┘

# %% [markdown]
# ### TOP-N Articles for a Topic

# %% [markdown]
# With this, we can finally extract the **TOP 3** articles about **Video Games**.

# %%
from functools import partial

select_topic = 1

def extract_topic_saturation(topic_id, vector):
    ts = {idx: value for (idx, value) in vector}
    return ts.get(topic_id, 0.0)

topic_saturation = list(map(partial(extract_topic_saturation, select_topic), by_get_document_topics))

# %%
import numpy as np

TOP_N = 3

top_idx = np.argsort(topic_saturation)[-TOP_N:]
top_saturations = [topic_saturation[i] for i in top_idx]
top_docs = [texts[i] for i in top_idx]

# %%
from termcolor import colored
from textwrap import fill

print(colored('Selected Topic:', attrs=['bold']), colored(f'{topic_names[select_topic]}', 'blue', attrs=['bold']), '\n')

for i, (idx, doc, sat) in enumerate(zip(top_idx, top_docs, top_saturations)):
    print(colored('Rank #', attrs=['bold']) + colored(f'{i+1:>2}', 'blue', attrs=['bold']) + ', ' +
          colored(f'Index #', attrs=['bold']) + colored(f'{idx}', 'green', attrs=['bold']) + ', ' +
          colored('Saturation: ', attrs=['bold']) + colored(f'{sat * 100.0:3.0f}%', 'green', attrs=['bold']) +
          '\n' +
          fill(doc, width=80))
    print('\n\n')
# Out:
# Selected Topic: #01
#
# Rank # 1, Index #1931, Saturation: 100%
# more power to the people says hp  the digital revolution is focused on letting
# people tell and share their own stories, according to carly fiorina, chief of
# technology giant hewlett packard.  the job of firms such as hp now, she said in
# a speech at the consumer electronics show (ces), was to ensure digital and
# physical worlds fully converged. she said the goal for 2005 was to make people
# the centre of technology. ces showcases 50,000 new gadgets that will be hitting
# the shelves in 2005. the tech-fest, the largest of its kind in the world, runs
# from 6 to 9 january. "the digital revolution is about the democratisation of
# technology and the experiences it makes possible," she told delegates.
# "revolution has always been about giving power to the people." she added: "the
# real story of the digital revolution is not just new products, but the millions
# of experiences made possible and stories that millions can tell." part of giving
# people more control has been about the freeing up of content, such as images,
# video and music. crucial to this has been the effort to make devices that speak
# to each other better so that content can be more easily transferred from one
# device, such as a digital camera, to others, such as portable media players. a
# lot of work still needs to be done, however, to sort out compatibility issues
# and standards within the technology industry so that gadgets just work
# seamlessly, she said.  ms fiorina's talk also touted the way technology is being
# designed to focus on lifestyle, fashion and personalisation, something she sees
# as key to what people want.  special guest, singer gwen stefani, joined her on-
# stage to promote her own range of hp digital cameras which ms stefani has helped
# design and which are heavily influenced by japanese youth culture. the digital
# cameras, which are due to go on sale in the us by the summer, are based on the
# hp 607 model. the emphasis on personalisation and lifestyle is a big theme at
# this year's ces, with tiny, wearable mp3 players at every turn and rainbow hues
# giving colour to everything. ms fiorina also announced that hp was working with
# nokia to launch a visual radio service for mobiles, which would launch in europe
# early this year. the service will let people listen to radio on their mobiles
# and download relevant content, like a track's ringtone, simultaneously. the
# service is designed to make mobile radio more interactive.  among the other new
# products she showcased was the digital media hub, a big upgrade to hp's digital
# entertainment centre. coming out in the autumn in the us, the box is a
# networked, high-definition tv, cable set-top box, digital video recorder and dvd
# recorder. it has a removable hard drive cartridge, memory card slots, and light
# scribe labelling software which lets people design and print customised dvd
# labels and covers. it is designed to contain all a household's digital media,
# such as pre-recorded tv shows, pictures, videos and music so it can all be
# managed in one place. the hub reflects the increasing move to re-box the pc so
# that it can work as part of other key centres of entertainment. research
# suggests that about 258 million images are saved and shared every day, equating
# to 94 billion a year. eighty per cent of those remain on cameras. media hubs are
# designed to encourage people to organise them on one box. ms fiorina was one of
# several keynote speakers, who also included microsoft chief bill gates, to set
# out what major technology companies think people will be doing with technologies
# and gadgets in the next 12 months. in a separate announcement during the keynote
# speech, ms fiorina said that hp would be partnering mtv to replace this year's
# mtv asia music award. mtv's asia aid will be held in bangkok on 3 february, and
# is aimed at helping to raise money for the asian tsunami disaster.
#
#
#
# Rank # 2, Index #2198, Saturation: 100%
# doors open at biggest gadget fair  thousands of technology lovers and industry
# experts have gathered in las vegas for the annual consumer electronics show
# (ces).  the fair showcases the latest technologies and gadgets that will hit the
# shops in the next year. about 50,000 new products will be unveiled as the show
# unfolds. microsoft chief bill gates is to make a pre-show keynote speech on
# wednesday when he is expected to announce details of the next generation xbox.
# the thrust of this year's show will be on technologies which put people in
# charge of multimedia content so they can store, listen to, and watch what they
# want on devices any time, anywhere. about 120,000 people are expected to attend
# the trade show which stretches over more than 1.5 million square feet.
# highlights will include the latest trends in digital imaging, storage
# technologies, thinner flat screen and high-definition tvs, wireless and portable
# technologies, gaming, and broadband technologies. the show also includes several
# speeches from key technology companies such as intel, microsoft, and hewlett
# packard among others. "the story this year remains all about digital and how
# that is completely transforming and revolutionising products and the way people
# interact with them," jeff joseph, from the consumer electronics association
# (cea) told the bbc news website. "it is about personalisation - taking your mp3
# player and creating your own playlist, taking your digital video recorder and
# watch what you want to watch when - you are no longer at the whim of the
# broadcasters."  consumer electronics and gadgets had a phenomenal year in 2004,
# according to figures released by ces organisers, the cea, on tuesday. the gadget
# explosion signalled the strongest growth yet in the us in 2004. shipments of
# consumer electronics rose by almost 11% between 2003 and 2004. that trend is
# predicted to continue, according to cea analysts, with wholesale shipments of
# consumer technologies expected to grow by 11% again in 2005. the fastest-growing
# technologies in 2004 included blank dvd media, liquid crystal display (lcd) tvs,
# digital video recorders (dvrs), and portable music players. "this year we will
# really begin to see that come to life in what we call place shifting - so if you
# have your pvr [personal video recorder] in your living room, you can move that
# content around the house. "some exhibitors will be showcasing how you can take
# that content anywhere," said mr joseph. he said the products which will be
# making waves in the next year will be about the "democratisation" of content -
# devices and technologies that will give people the freedom to do more with
# music, video, and images. there will also be more focus on the design of
# technologies, following the lead that apple's ipod made, with ease of use and
# good looks which appeal to a wider range of people a key concern.  the cea
# predicted that there would be several key technology trends to watch in the
# coming year. gaming would continue to thrive, especially on mobile devices, and
# would reach out to more diverse gamers such as women. games consoles sales have
# been declining, but the launch of next generation consoles, such as microsoft's
# xbox and playstation, could buoy up sales. although it has been widely predicted
# that mr gates would be showcasing the new xbox, some media reports have cast
# doubt on what he would be talking about in the keynote. some have suggested the
# announcement may take place at the games developers conference in the summer
# instead. with more than 52% of us homes expected to have home networks, the cea
# suggested hard drive boxes - or media servers - capable of storing thousands of
# images, video and audio files to be accessed through other devices around the
# home, will be more commonplace. portable devices that combine mobile telephony,
# digital music and video players, will also be more popular in 2005. their
# popularity will be driven by more multimedia content and services which will let
# people watch and listen to films, tv, and audio wherever they are. this means
# more storage technologies will be in demand, such as external hard drives, and
# flash memory like sd cards. ces runs officially from 6 to 9 january.
#
#
#
# Rank # 3, Index #1919, Saturation: 100%
# doors open at biggest gadget fair  thousands of technology lovers and industry
# experts have gathered in las vegas for the annual consumer electronics show
# (ces).  the fair showcases the latest technologies and gadgets that will hit the
# shops in the next year. about 50,000 new products will be unveiled as the show
# unfolds. microsoft chief bill gates is to make a pre-show keynote speech on
# wednesday when he is expected to announce details of the next generation xbox.
# the thrust of this year's show will be on technologies which put people in
# charge of multimedia content so they can store, listen to, and watch what they
# want on devices any time, anywhere. about 120,000 people are expected to attend
# the trade show which stretches over more than 1.5 million square feet.
# highlights will include the latest trends in digital imaging, storage
# technologies, thinner flat screen and high-definition tvs, wireless and portable
# technologies, gaming, and broadband technologies. the show also includes several
# speeches from key technology companies such as intel, microsoft, and hewlett
# packard among others. "the story this year remains all about digital and how
# that is completely transforming and revolutionising products and the way people
# interact with them," jeff joseph, from the consumer electronics association
# (cea) told the bbc news website. "it is about personalisation - taking your mp3
# player and creating your own playlist, taking your digital video recorder and
# watch what you want to watch when - you are no longer at the whim of the
# broadcasters."  consumer electronics and gadgets had a phenomenal year in 2004,
# according to figures released by ces organisers, the cea, on tuesday. the gadget
# explosion signalled the strongest growth yet in the us in 2004. shipments of
# consumer electronics rose by almost 11% between 2003 and 2004. that trend is
# predicted to continue, according to cea analysts, with wholesale shipments of
# consumer technologies expected to grow by 11% again in 2005. the fastest-growing
# technologies in 2004 included blank dvd media, liquid crystal display (lcd) tvs,
# digital video recorders (dvrs), and portable music players. "this year we will
# really begin to see that come to life in what we call place shifting - so if you
# have your pvr [personal video recorder] in your living room, you can move that
# content around the house. "some exhibitors will be showcasing how you can take
# that content anywhere," said mr joseph. he said the products which will be
# making waves in the next year will be about the "democratisation" of content -
# devices and technologies that will give people the freedom to do more with
# music, video, and images. there will also be more focus on the design of
# technologies, following the lead that apple's ipod made, with ease of use and
# good looks which appeal to a wider range of people a key concern.  the cea
# predicted that there would be several key technology trends to watch in the
# coming year. gaming would continue to thrive, especially on mobile devices, and
# would reach out to more diverse gamers such as women. games consoles sales have
# been declining, but the launch of next generation consoles, such as microsoft's
# xbox and playstation, could buoy up sales. although it has been widely predicted
# that mr gates would be showcasing the new xbox, some media reports have cast
# doubt on what he would be talking about in the keynote. some have suggested the
# announcement may take place at the games developers conference in the summer
# instead. with more than 52% of us homes expected to have home networks, the cea
# suggested hard drive boxes - or media servers - capable of storing thousands of
# images, video and audio files to be accessed through other devices around the
# home, will be more commonplace. portable devices that combine mobile telephony,
# digital music and video players, will also be more popular in 2005. their
# popularity will be driven by more multimedia content and services which will let
# people watch and listen to films, tv, and audio wherever they are. this means
# more storage technologies will be in demand, such as external hard drives, and
# flash memory like sd cards. ces runs officially from 6 to 9 january.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# To evaluate a topic model, we use a `Coherence Score`. The higher the better.
#
# * Resource reading: [Blog Post by Quentin Pleplé](http://qpleple.com/topic-coherence-to-evaluate-topic-models/)
#
# We present 3 different scores, their definition and usage is out of scope for this class:
# * UCI score
# * UMASS score
# * $\textrm{C}_V$ score
#
# As an external resource:
# * [Röder et al., 2015](http://svn.aksw.org/papers/2015/WSDM_Topic_Evaluation/public.pdf) "Exploring the Space of Topic Coherence Measures".

# %%
from gensim.models import CoherenceModel

# Compute Coherence Score
coherence_uci = CoherenceModel(
    model=lda,
    texts=stopped_tokenized,
    dictionary=dictionary,
    coherence='c_uci'
)
uci = coherence_uci.get_coherence()

# %%
# Compute Coherence Score
coherence_umass = CoherenceModel(
    model=lda,
    corpus=corpus,
    dictionary=dictionary,
    coherence='u_mass'
)
umass = coherence_umass.get_coherence()

# %%
# Compute Coherence Score
coherence_cv = CoherenceModel(
    model=lda,
    texts=stopped_tokenized,
    dictionary=dictionary,
    coherence='c_v'
)
c_v = coherence_cv.get_coherence()

# %%
print(f'UCI  : {uci:.2f}')
print(f'UMASS: {umass:.2f}')
print(f'C_V  : {c_v:+.2f}')
# Out:
# UCI  : -1.46
# UMASS: -2.26
# C_V  : +0.50

# %% [markdown]
# # Optimize for Topic Coherence

# %% [markdown]
# We can use the evaluation metric `coherence` to select the optimum number of topics.
#
# It is a self-made grid search.
#
# There are many other parameters that we could tweak as well, and incorporate in the grid search (`alpha`, `eta` for example).
#
# The `LdaMulticore` class has an implementation for LDA optmized for parallel processing, if your CPu has more than 1 core. Use it instead of `LdaModel`, the interface is the same.
#
# * [`LdaMulticore` documentation](https://radimrehurek.com/gensim/models/ldamulticore.html)
#
# **Warning** Usual runtime is 10 minutes.

# %%
MULTICORE = False   # Switch True to use on your own multicore laptop

# %%
import tqdm
import logging

from gensim.models import CoherenceModel
from gensim.models import LdaMulticore

gensim_logger = logging.getLogger('gensim.models.ldamodel')
gensim_logger.setLevel(logging.DEBUG)

history = []
Ks = [4, 6, 8, 10, 20, 50, 100]

for K in tqdm.tqdm(Ks):
    if MULTICORE:
        import psutil
        NUM_CORES = psutil.cpu_count(logical=False)

        lda_k = LdaMulticore(
            corpus=corpus,
            id2word=dictionary,
            num_topics=K,
            iterations=100,
            passes=20,
            eval_every=None,
            random_state=42,
            workers=NUM_CORES - 1              # Adjust it to your computer: Number of CPU Cores - 1
        )
    else:
        lda_k = LdaModel(
            corpus=corpus,
            id2word=dictionary,
            num_topics=K,
            iterations=100,
            passes=20,
            eval_every=None,
            random_state=42,
        )

    coherence_uci = CoherenceModel(
        model=lda_k,
        texts=stopped_tokenized,
        dictionary=dictionary,
        coherence='c_uci'
    )
    uci = coherence_uci.get_coherence()

    coherence_umass = CoherenceModel(
        model=lda_k,
        corpus=corpus,
        dictionary=dictionary,
        coherence='u_mass'
    )
    umass = coherence_umass.get_coherence()

    coherence_cv = CoherenceModel(
        model=lda_k,
        texts=stopped_tokenized,
        dictionary=dictionary,
        coherence='c_v'
    )
    c_v = coherence_cv.get_coherence()

    history.append({'K': K, 'model': lda_k, 'c_v': c_v, 'umass': umass, 'uci': uci})
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]INFO:gensim.models.ldamodel:using symmetric alpha at 0.25
# INFO:gensim.models.ldamodel:using symmetric eta at 0.25
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamodel:running online (multi-pass) LDA training, 4 topics, 20 passes over the supplied corpus of 2225 documents, updating model once every 2000 documents, evaluating perplexity every 0 documents, iterating 100x with a convergence threshold of 0.001000
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:49/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.005*"people" + 0.004*"new" + 0.003*"world" + 0.003*"year" + 0.003*"he_said" + 0.003*"uk" + 0.003*"labour" + 0.003*"time" + 0.003*"government" + 0.002*"says"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.005*"new" + 0.004*"year" + 0.004*"people" + 0.004*"will_be" + 0.004*"government" + 0.003*"he_said" + 0.003*"game" + 0.003*"time" + 0.003*"labour" + 0.003*"uk"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.008*"year" + 0.004*"best" + 0.004*"people" + 0.004*"new" + 0.003*"time" + 0.003*"world" + 0.003*"years" + 0.002*"music" + 0.002*"he_said" + 0.002*"film"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.005*"year" + 0.004*"new" + 0.003*"government" + 0.003*"people" + 0.003*"film" + 0.003*"world" + 0.003*"he_said" + 0.003*"will_be" + 0.003*"years" + 0.002*"time"
# INFO:gensim.models.ldamodel:topic diff=1.121554, rho=1.000000
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:83/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.007*"people" + 0.005*"world" + 0.004*"new" + 0.004*"says" + 0.004*"information" + 0.004*"he_said" + 0.003*"system" + 0.003*"technology" + 0.003*"software" + 0.003*"use"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.007*"mobile" + 0.007*"people" + 0.006*"technology" + 0.006*"games" + 0.006*"new" + 0.006*"will_be" + 0.005*"game" + 0.005*"video" + 0.005*"phone" + 0.004*"digital"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.008*"people" + 0.006*"software" + 0.006*"users" + 0.005*"microsoft" + 0.005*"new" + 0.005*"year" + 0.005*"music" + 0.004*"search" + 0.004*"security" + 0.004*"mobile"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.005*"year" + 0.004*"new" + 0.004*"people" + 0.003*"will_be" + 0.003*"company" + 0.003*"internet" + 0.003*"he_said" + 0.003*"has_been" + 0.003*"government" + 0.002*"film"
# INFO:gensim.models.ldamodel:topic diff=1.096753, rho=0.707107
# INFO:gensim.models.ldamodel:PROGRESS: pass 1, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1503/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.007*"people" + 0.004*"new" + 0.004*"he_said" + 0.004*"world" + 0.003*"says" + 0.003*"party" + 0.003*"labour" + 0.003*"election" + 0.003*"uk" + 0.003*"government"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.007*"people" + 0.006*"mobile" + 0.006*"new" + 0.006*"games" + 0.005*"game" + 0.005*"technology" + 0.005*"will_be" + 0.005*"tv" + 0.004*"digital" + 0.004*"video"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.007*"people" + 0.006*"music" + 0.005*"users" + 0.005*"year" + 0.005*"software" + 0.005*"new" + 0.005*"microsoft" + 0.004*"search" + 0.004*"security" + 0.003*"net"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.006*"year" + 0.004*"new" + 0.003*"government" + 0.003*"film" + 0.003*"time" + 0.003*"years" + 0.003*"will_be" + 0.003*"best" + 0.003*"he_said" + 0.002*"world"
# INFO:gensim.models.ldamodel:topic diff=0.448470, rho=0.566820
# INFO:gensim.models.ldamodel:PROGRESS: pass 1, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:197/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.007*"people" + 0.005*"world" + 0.005*"new" + 0.004*"says" + 0.004*"information" + 0.004*"he_said" + 0.003*"software" + 0.003*"system" + 0.003*"internet" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.009*"mobile" + 0.008*"people" + 0.007*"technology" + 0.006*"games" + 0.006*"will_be" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"phone" + 0.005*"digital"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.009*"people" + 0.007*"software" + 0.007*"users" + 0.006*"microsoft" + 0.005*"new" + 0.005*"search" + 0.005*"music" + 0.005*"security" + 0.005*"online" + 0.004*"net"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.006*"year" + 0.004*"new" + 0.003*"government" + 0.003*"film" + 0.003*"will_be" + 0.002*"years" + 0.002*"has_been" + 0.002*"time" + 0.002*"he_said" + 0.002*"company"
# INFO:gensim.models.ldamodel:topic diff=0.676273, rho=0.566820
# INFO:gensim.models.ldamodel:PROGRESS: pass 2, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1831/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.008*"people" + 0.004*"new" + 0.004*"world" + 0.004*"says" + 0.004*"he_said" + 0.004*"party" + 0.003*"government" + 0.003*"labour" + 0.003*"public" + 0.003*"election"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.008*"mobile" + 0.008*"people" + 0.007*"technology" + 0.006*"games" + 0.006*"new" + 0.005*"will_be" + 0.005*"game" + 0.005*"video" + 0.005*"tv" + 0.005*"digital"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.009*"people" + 0.007*"software" + 0.007*"users" + 0.006*"music" + 0.005*"microsoft" + 0.005*"new" + 0.005*"search" + 0.005*"security" + 0.005*"net" + 0.004*"online"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.006*"year" + 0.004*"new" + 0.003*"government" + 0.003*"time" + 0.003*"best" + 0.003*"film" + 0.003*"years" + 0.003*"will_be" + 0.003*"world" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.271596, rho=0.493114
# INFO:gensim.models.ldamodel:PROGRESS: pass 2, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:216/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.008*"people" + 0.005*"world" + 0.005*"new" + 0.005*"says" + 0.004*"information" + 0.004*"he_said" + 0.003*"software" + 0.003*"service" + 0.003*"system" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.009*"mobile" + 0.008*"people" + 0.007*"technology" + 0.006*"games" + 0.005*"will_be" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"digital" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.009*"people" + 0.008*"software" + 0.007*"users" + 0.006*"microsoft" + 0.006*"search" + 0.005*"security" + 0.005*"new" + 0.005*"net" + 0.005*"online" + 0.005*"music"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.006*"year" + 0.004*"new" + 0.003*"government" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"will_be" + 0.003*"world" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.507533, rho=0.493114
# INFO:gensim.models.ldamodel:PROGRESS: pass 3, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1907/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.009*"people" + 0.005*"new" + 0.005*"says" + 0.004*"world" + 0.004*"he_said" + 0.004*"party" + 0.004*"government" + 0.003*"public" + 0.003*"information" + 0.003*"law"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.009*"mobile" + 0.008*"people" + 0.007*"technology" + 0.006*"games" + 0.005*"new" + 0.005*"will_be" + 0.005*"video" + 0.005*"digital" + 0.005*"tv" + 0.005*"music"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.009*"people" + 0.007*"software" + 0.007*"users" + 0.006*"microsoft" + 0.005*"search" + 0.005*"music" + 0.005*"security" + 0.005*"new" + 0.005*"net" + 0.005*"online"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.006*"year" + 0.004*"new" + 0.003*"time" + 0.003*"best" + 0.003*"government" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.207271, rho=0.442266
# INFO:gensim.models.ldamodel:PROGRESS: pass 3, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:220/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.008*"people" + 0.005*"world" + 0.005*"new" + 0.005*"says" + 0.004*"information" + 0.004*"he_said" + 0.003*"service" + 0.003*"software" + 0.003*"public" + 0.003*"government"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"technology" + 0.007*"games" + 0.005*"will_be" + 0.005*"new" + 0.005*"video" + 0.005*"digital" + 0.005*"phone" + 0.005*"game"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.009*"people" + 0.008*"software" + 0.008*"users" + 0.006*"microsoft" + 0.006*"search" + 0.006*"security" + 0.005*"net" + 0.005*"new" + 0.005*"online" + 0.005*"he_said"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"government" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.383536, rho=0.442266
# INFO:gensim.models.ldamodel:PROGRESS: pass 4, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1933/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.009*"people" + 0.005*"new" + 0.005*"says" + 0.004*"world" + 0.004*"government" + 0.004*"he_said" + 0.004*"party" + 0.004*"public" + 0.003*"information" + 0.003*"law"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.009*"mobile" + 0.008*"people" + 0.007*"technology" + 0.007*"games" + 0.005*"new" + 0.005*"music" + 0.005*"will_be" + 0.005*"video" + 0.005*"digital" + 0.005*"tv"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.009*"people" + 0.008*"software" + 0.008*"users" + 0.006*"microsoft" + 0.006*"search" + 0.006*"security" + 0.005*"net" + 0.005*"new" + 0.005*"online" + 0.005*"he_said"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"government" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.185501, rho=0.404474
# INFO:gensim.models.ldamodel:PROGRESS: pass 4, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:220/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.009*"people" + 0.005*"world" + 0.005*"new" + 0.005*"says" + 0.004*"information" + 0.004*"he_said" + 0.004*"service" + 0.004*"government" + 0.003*"software" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"technology" + 0.007*"games" + 0.005*"new" + 0.005*"will_be" + 0.005*"video" + 0.005*"music" + 0.005*"phone" + 0.005*"digital"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.009*"people" + 0.008*"software" + 0.008*"users" + 0.007*"microsoft" + 0.006*"search" + 0.006*"security" + 0.005*"net" + 0.005*"online" + 0.005*"new" + 0.005*"he_said"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"government" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.302062, rho=0.404474
# INFO:gensim.models.ldamodel:PROGRESS: pass 5, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1953/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"says" + 0.005*"government" + 0.004*"world" + 0.004*"he_said" + 0.004*"party" + 0.004*"public" + 0.004*"information" + 0.003*"law"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.009*"mobile" + 0.008*"people" + 0.007*"technology" + 0.007*"games" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"digital" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.008*"software" + 0.008*"users" + 0.006*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"new" + 0.005*"he_said"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"government" + 0.003*"world" + 0.003*"will_be" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.174545, rho=0.374963
# INFO:gensim.models.ldamodel:PROGRESS: pass 5, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:221/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.009*"people" + 0.005*"new" + 0.005*"world" + 0.005*"says" + 0.004*"information" + 0.004*"government" + 0.004*"service" + 0.004*"he_said" + 0.003*"online" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"technology" + 0.007*"games" + 0.005*"new" + 0.005*"will_be" + 0.005*"video" + 0.005*"music" + 0.005*"phone" + 0.005*"game"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.008*"software" + 0.008*"users" + 0.007*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"new" + 0.005*"he_said"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"government" + 0.003*"world" + 0.003*"will_be" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.249803, rho=0.374963
# INFO:gensim.models.ldamodel:PROGRESS: pass 6, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1957/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"says" + 0.005*"government" + 0.005*"world" + 0.004*"he_said" + 0.004*"public" + 0.004*"information" + 0.004*"party" + 0.003*"law"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"digital" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.008*"software" + 0.008*"users" + 0.006*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"new" + 0.005*"he_said"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.003*"government" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.166561, rho=0.351093
# INFO:gensim.models.ldamodel:PROGRESS: pass 6, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:221/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.009*"people" + 0.005*"new" + 0.005*"world" + 0.005*"says" + 0.004*"information" + 0.004*"government" + 0.004*"service" + 0.004*"he_said" + 0.003*"online" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.005*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"phone" + 0.005*"game"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.008*"users" + 0.007*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"new" + 0.005*"he_said"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.003*"government" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.215837, rho=0.351093
# INFO:gensim.models.ldamodel:PROGRESS: pass 7, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1955/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"government" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"party" + 0.003*"law"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"digital" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.008*"software" + 0.008*"users" + 0.006*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"new" + 0.005*"he_said"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.003*"government" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.159213, rho=0.331269
# INFO:gensim.models.ldamodel:PROGRESS: pass 7, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:220/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.009*"people" + 0.005*"new" + 0.005*"world" + 0.005*"says" + 0.004*"information" + 0.004*"government" + 0.004*"service" + 0.004*"he_said" + 0.003*"online" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"game" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.008*"users" + 0.007*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"new" + 0.005*"he_said"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"government" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.192724, rho=0.331269
# INFO:gensim.models.ldamodel:PROGRESS: pass 8, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1963/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"government" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"party" + 0.003*"law"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"digital" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.008*"software" + 0.008*"users" + 0.007*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"new" + 0.005*"he_said"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"government" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.152248, rho=0.314464
# INFO:gensim.models.ldamodel:PROGRESS: pass 8, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:221/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.009*"people" + 0.005*"new" + 0.005*"world" + 0.005*"says" + 0.004*"government" + 0.004*"information" + 0.004*"service" + 0.004*"he_said" + 0.003*"system" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"game" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.008*"users" + 0.007*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"government" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.175888, rho=0.314464
# INFO:gensim.models.ldamodel:PROGRESS: pass 9, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1966/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"government" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"service" + 0.003*"law"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"digital" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.008*"software" + 0.008*"users" + 0.007*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"government" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.145677, rho=0.299981
# INFO:gensim.models.ldamodel:PROGRESS: pass 9, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:222/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"world" + 0.005*"says" + 0.005*"government" + 0.004*"information" + 0.004*"service" + 0.004*"he_said" + 0.003*"system" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"game" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"government" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.162869, rho=0.299981
# INFO:gensim.models.ldamodel:PROGRESS: pass 10, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1966/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"government" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"service" + 0.003*"system"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"game" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.008*"users" + 0.007*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"government" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.139606, rho=0.287331
# INFO:gensim.models.ldamodel:PROGRESS: pass 10, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:223/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"world" + 0.005*"says" + 0.005*"government" + 0.004*"information" + 0.004*"service" + 0.004*"he_said" + 0.003*"system" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"game" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"government" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.152383, rho=0.287331
# INFO:gensim.models.ldamodel:PROGRESS: pass 11, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1969/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.006*"government" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"service" + 0.003*"system"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.006*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"game" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.008*"users" + 0.007*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"government" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.134023, rho=0.276158
# INFO:gensim.models.ldamodel:PROGRESS: pass 11, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:223/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"world" + 0.005*"says" + 0.005*"government" + 0.004*"information" + 0.004*"service" + 0.004*"he_said" + 0.003*"system" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"game" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"has_been" + 0.002*"government"
# INFO:gensim.models.ldamodel:topic diff=0.143807, rho=0.276158
# INFO:gensim.models.ldamodel:PROGRESS: pass 12, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1968/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.006*"government" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"service" + 0.003*"system"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.006*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"game" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"he_said" + 0.002*"government"
# INFO:gensim.models.ldamodel:topic diff=0.128967, rho=0.266194
# INFO:gensim.models.ldamodel:PROGRESS: pass 12, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:223/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"world" + 0.005*"says" + 0.005*"government" + 0.004*"information" + 0.004*"service" + 0.004*"he_said" + 0.004*"system" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"will_be" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"has_been" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.136588, rho=0.266194
# INFO:gensim.models.ldamodel:PROGRESS: pass 13, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1969/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.006*"government" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"service" + 0.003*"system"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.006*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"will_be" + 0.005*"game" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.006*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"he_said" + 0.002*"government"
# INFO:gensim.models.ldamodel:topic diff=0.124383, rho=0.257236
# INFO:gensim.models.ldamodel:PROGRESS: pass 13, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:223/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.005*"government" + 0.004*"information" + 0.004*"he_said" + 0.004*"service" + 0.004*"system" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"will_be" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"has_been" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.130422, rho=0.257236
# INFO:gensim.models.ldamodel:PROGRESS: pass 14, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1970/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.006*"government" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"service" + 0.003*"system"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.006*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"will_be" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"he_said" + 0.002*"government"
# INFO:gensim.models.ldamodel:topic diff=0.120238, rho=0.249126
# INFO:gensim.models.ldamodel:PROGRESS: pass 14, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:223/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.005*"government" + 0.004*"information" + 0.004*"he_said" + 0.004*"service" + 0.004*"system" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"will_be" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"has_been" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.125057, rho=0.249126
# INFO:gensim.models.ldamodel:PROGRESS: pass 15, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1974/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.006*"government" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"service" + 0.003*"system"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.006*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"will_be" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"he_said" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.116412, rho=0.241737
# INFO:gensim.models.ldamodel:PROGRESS: pass 15, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:223/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.005*"government" + 0.004*"information" + 0.004*"he_said" + 0.004*"service" + 0.004*"system" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"will_be" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"has_been" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.120324, rho=0.241737
# INFO:gensim.models.ldamodel:PROGRESS: pass 16, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1969/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.006*"government" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"service" + 0.003*"system"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.006*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"will_be" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"he_said" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.112893, rho=0.234969
# INFO:gensim.models.ldamodel:PROGRESS: pass 16, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:223/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"government" + 0.005*"says" + 0.005*"world" + 0.004*"information" + 0.004*"he_said" + 0.004*"service" + 0.004*"system" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"will_be" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"has_been" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.116087, rho=0.234969
# INFO:gensim.models.ldamodel:PROGRESS: pass 17, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1971/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.006*"government" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"service" + 0.003*"system"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.006*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"will_be" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"he_said" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.109606, rho=0.228740
# INFO:gensim.models.ldamodel:PROGRESS: pass 17, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:222/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.005*"new" + 0.005*"government" + 0.005*"says" + 0.005*"world" + 0.004*"information" + 0.004*"he_said" + 0.004*"service" + 0.004*"system" + 0.003*"public"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.007*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"game" + 0.005*"video" + 0.005*"will_be" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.006*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.004*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"has_been" + 0.002*"he_said"
# INFO:gensim.models.ldamodel:topic diff=0.112264, rho=0.228740
# INFO:gensim.models.ldamodel:PROGRESS: pass 18, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1972/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.010*"people" + 0.006*"government" + 0.005*"new" + 0.005*"says" + 0.005*"world" + 0.004*"he_said" + 0.004*"information" + 0.004*"public" + 0.003*"service" + 0.003*"system"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.010*"mobile" + 0.008*"people" + 0.007*"games" + 0.006*"technology" + 0.006*"music" + 0.005*"new" + 0.005*"video" + 0.005*"game" + 0.005*"will_be" + 0.005*"phone"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.010*"people" + 0.009*"software" + 0.009*"users" + 0.007*"microsoft" + 0.007*"search" + 0.006*"security" + 0.006*"net" + 0.005*"online" + 0.005*"he_said" + 0.005*"new"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.007*"year" + 0.004*"new" + 0.003*"best" + 0.003*"time" + 0.003*"film" + 0.003*"years" + 0.003*"world" + 0.003*"will_be" + 0.002*"he_said" + 0.002*"has_been"
# INFO:gensim.models.ldamodel:topic diff=0.106581, rho=0.222981
# INFO:gensim.models.ldamodel:PROGRESS: pass 18, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# ...
# INFO:gensim.models.ldamodel:topic #18 (0.010): 0.041*"machines" + 0.020*"cash" + 0.019*"he_said" + 0.018*"security" + 0.015*"networks" + 0.015*"information" + 0.014*"banks" + 0.014*"network" + 0.012*"viruses" + 0.012*"they_are"
# INFO:gensim.models.ldamodel:topic #66 (0.010): 0.041*"posters" + 0.027*"browser" + 0.026*"campaign" + 0.023*"ie" + 0.019*"postal" + 0.018*"number" + 0.018*"poster" + 0.017*"chart" + 0.016*"including" + 0.015*"information"
# INFO:gensim.models.ldamodel:topic #78 (0.010): 0.060*"online" + 0.032*"people" + 0.021*"blogs" + 0.021*"internet" + 0.020*"web" + 0.018*"pew" + 0.018*"blog" + 0.015*"report" + 0.015*"found" + 0.013*"survey"
# INFO:gensim.models.ldamodel:topic #40 (0.010): 0.100*"music" + 0.039*"band" + 0.027*"project" + 0.022*"song" + 0.018*"concert" + 0.017*"pop" + 0.017*"group" + 0.016*"songs" + 0.016*"sound" + 0.014*"years"
# INFO:gensim.models.ldamodel:topic diff=inf, rho=0.249126
# INFO:gensim.models.ldamodel:PROGRESS: pass 15, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:2000/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #28 (0.010): 0.031*"sony" + 0.017*"technology" + 0.016*"microsoft" + 0.013*"playstation" + 0.012*"toshiba" + 0.011*"year" + 0.011*"programmes" + 0.009*"video" + 0.008*"tv" + 0.007*"content"
# INFO:gensim.models.ldamodel:topic #41 (0.010): 0.029*"bond" + 0.027*"campbell" + 0.024*"picture" + 0.016*"film" + 0.014*"gained" + 0.013*"maker" + 0.013*"stories" + 0.012*"tom" + 0.011*"jewish" + 0.011*"apologise"
# INFO:gensim.models.ldamodel:topic #90 (0.010): 0.122*"apple" + 0.063*"information" + 0.041*"sources" + 0.029*"information_about" + 0.022*"reporters" + 0.022*"reveal" + 0.021*"asked" + 0.017*"product" + 0.016*"online" + 0.015*"fight"
# INFO:gensim.models.ldamodel:topic #64 (0.010): 0.016*"world" + 0.014*"will_be" + 0.014*"new" + 0.010*"players" + 0.009*"year" + 0.009*"game" + 0.009*"he_said" + 0.008*"event" + 0.007*"time" + 0.006*"open"
# INFO:gensim.models.ldamodel:topic #68 (0.010): 0.015*"time" + 0.010*"football" + 0.010*"manager" + 0.008*"year" + 0.008*"team" + 0.008*"game" + 0.007*"like" + 0.007*"told" + 0.007*"has_been" + 0.006*"want"
# INFO:gensim.models.ldamodel:topic diff=inf, rho=0.241737
# INFO:gensim.models.ldamodel:PROGRESS: pass 15, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:225/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #8 (0.010): 0.034*"iran" + 0.027*"died" + 0.025*"team" + 0.017*"evolved" + 0.016*"attended" + 0.015*"project" + 0.015*"star" + 0.015*"release" + 0.015*"embarrassing" + 0.014*"wilson"
# INFO:gensim.models.ldamodel:topic #55 (0.010): 0.030*"million" + 0.026*"media" + 0.020*"students" + 0.018*"february" + 0.018*"14" + 0.017*"ideas" + 0.016*"area" + 0.016*"campaign" + 0.013*"attempt" + 0.013*"an_attempt"
# INFO:gensim.models.ldamodel:topic #20 (0.010): 0.024*"service" + 0.023*"people" + 0.018*"calls" + 0.013*"users" + 0.013*"access" + 0.013*"phone" + 0.012*"net" + 0.011*"free" + 0.007*"world" + 0.007*"available"
# INFO:gensim.models.ldamodel:topic #31 (0.010): 0.022*"iraq" + 0.019*"west" + 0.019*"city" + 0.018*"chosen" + 0.016*"meet" + 0.015*"rooney" + 0.015*"canada" + 0.014*"appear" + 0.013*"model" + 0.012*"taken"
# INFO:gensim.models.ldamodel:topic #5 (0.010): 0.028*"site" + 0.026*"mail" + 0.018*"people" + 0.017*"donations" + 0.016*"cash" + 0.015*"message" + 0.015*"online" + 0.012*"tsunami" + 0.012*"website" + 0.011*"dec"
# INFO:gensim.models.ldamodel:topic diff=inf, rho=0.241737
# INFO:gensim.models.ldamodel:PROGRESS: pass 16, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:2000/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #79 (0.010): 0.023*"patents" + 0.014*"offer" + 0.011*"orchestra" + 0.011*"sports" + 0.010*"like" + 0.009*"moves" + 0.008*"software" + 0.008*"time" + 0.008*"ibm" + 0.008*"years"
# INFO:gensim.models.ldamodel:topic #47 (0.010): 0.039*"chip" + 0.026*"cell" + 0.019*"intel" + 0.018*"laser" + 0.015*"light" + 0.013*"chips" + 0.013*"data" + 0.012*"silicon" + 0.011*"he_said" + 0.010*"inside"
# INFO:gensim.models.ldamodel:topic #77 (0.010): 0.042*"office" + 0.028*"box" + 0.021*"ps2" + 0.020*"box_office" + 0.017*"information" + 0.016*"original" + 0.014*"may_be" + 0.014*"head" + 0.013*"sequel" + 0.013*"had_been"
# INFO:gensim.models.ldamodel:topic #51 (0.010): 0.016*"games" + 0.016*"game" + 0.011*"time" + 0.011*"maps" + 0.010*"play" + 0.010*"way" + 0.009*"gameboy" + 0.008*"digital" + 0.008*"you_can" + 0.007*"mobile"
# INFO:gensim.models.ldamodel:topic #64 (0.010): 0.016*"world" + 0.015*"will_be" + 0.014*"new" + 0.010*"players" + 0.009*"year" + 0.009*"he_said" + 0.008*"game" + 0.008*"event" + 0.007*"time" + 0.006*"open"
# INFO:gensim.models.ldamodel:topic diff=inf, rho=0.234969
# INFO:gensim.models.ldamodel:PROGRESS: pass 16, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:225/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #57 (0.010): 0.018*"olympic" + 0.014*"drugs" + 0.014*"race" + 0.012*"year" + 0.012*"athens" + 0.012*"champion" + 0.011*"men" + 0.011*"indoor" + 0.010*"gold" + 0.010*"world"
# INFO:gensim.models.ldamodel:topic #59 (0.010): 0.016*"will_be" + 0.015*"second" + 0.014*"year" + 0.014*"mp3_players" + 0.010*"broadband" + 0.010*"likely" + 0.010*"per_second" + 0.009*"times" + 0.009*"americans" + 0.009*"ibm"
# INFO:gensim.models.ldamodel:topic #40 (0.010): 0.103*"music" + 0.039*"band" + 0.027*"project" + 0.023*"song" + 0.018*"pop" + 0.017*"concert" + 0.017*"group" + 0.016*"songs" + 0.016*"sound" + 0.014*"years"
# INFO:gensim.models.ldamodel:topic #6 (0.010): 0.013*"will_be" + 0.011*"women" + 0.010*"says" + 0.009*"like" + 0.009*"..." + 0.008*"people" + 0.008*"new" + 0.007*"important" + 0.007*"time" + 0.007*"should_be"
# INFO:gensim.models.ldamodel:topic #58 (0.010): 0.049*"eu" + 0.042*"law" + 0.041*"human" + 0.030*"laws" + 0.024*"ruling" + 0.024*"rules" + 0.022*"human_rights" + 0.022*"european" + 0.021*"rights" + 0.016*"member"
# INFO:gensim.models.ldamodel:topic diff=inf, rho=0.234969
# INFO:gensim.models.ldamodel:PROGRESS: pass 17, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:2000/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #36 (0.010): 0.014*"o'gara" + 0.012*"cards" + 0.010*"firm" + 0.010*"email" + 0.010*"systems" + 0.010*"attacks" + 0.009*"traffic" + 0.009*"murphy" + 0.009*"mail" + 0.009*"bell"
# INFO:gensim.models.ldamodel:topic #99 (0.010): 0.028*"ukip" + 0.027*"kilroy" + 0.025*"ask" + 0.025*"silk" + 0.020*"jeeves" + 0.018*"ask_jeeves" + 0.012*"mr_kilroy" + 0.012*"he_said" + 0.010*"search" + 0.010*"rely"
# INFO:gensim.models.ldamodel:topic #95 (0.010): 0.024*"site" + 0.020*"sites" + 0.015*"bush" + 0.013*"traffic" + 0.011*"campaign" + 0.010*"websites" + 0.009*"computer" + 0.009*"software" + 0.009*"attack" + 0.008*"wong"
# INFO:gensim.models.ldamodel:topic #4 (0.010): 0.025*"growth" + 0.014*"economy" + 0.014*"year" + 0.013*"rate" + 0.011*"rise" + 0.010*"interest" + 0.010*"fall" + 0.009*"rates" + 0.009*"bank" + 0.009*"years"
# INFO:gensim.models.ldamodel:topic #43 (0.010): 0.069*"aid" + 0.028*"disaster" + 0.025*"relief" + 0.024*"tsunami" + 0.022*"world" + 0.021*"help" + 0.018*"text" + 0.015*"people" + 0.014*"agencies" + 0.013*"republic"
# INFO:gensim.models.ldamodel:topic diff=inf, rho=0.228740
# INFO:gensim.models.ldamodel:PROGRESS: pass 17, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:225/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #81 (0.010): 0.015*"company" + 0.014*"market" + 0.013*"hour" + 0.012*"developed" + 0.011*"control" + 0.011*"colour" + 0.011*"mobile_gaming" + 0.011*"cost" + 0.011*"2005" + 0.010*"device"
# INFO:gensim.models.ldamodel:topic #60 (0.010): 0.050*"nintendo" + 0.037*"ds" + 0.034*"gaming" + 0.025*"games" + 0.024*"handheld" + 0.022*"console" + 0.020*"gamers" + 0.018*"sony" + 0.018*"game" + 0.017*"psp"
# INFO:gensim.models.ldamodel:topic #46 (0.010): 0.032*"ebay" + 0.016*"numbers" + 0.016*"bt" + 0.015*"modem" + 0.014*"premium" + 0.014*"find" + 0.013*"dial" + 0.013*"dial_up" + 0.013*"phone" + 0.013*"rate"
# INFO:gensim.models.ldamodel:topic #25 (0.010): 0.026*"file" + 0.020*"music" + 0.018*"industry" + 0.018*"sharing" + 0.018*"legal" + 0.017*"peer" + 0.017*"bittorrent" + 0.017*"networks" + 0.016*"files" + 0.014*"file_sharing"
# INFO:gensim.models.ldamodel:topic #43 (0.010): 0.066*"aid" + 0.027*"disaster" + 0.023*"world" + 0.023*"relief" + 0.021*"text" + 0.021*"help" + 0.020*"tsunami" + 0.016*"agencies" + 0.016*"people" + 0.014*"human"
# INFO:gensim.models.ldamodel:topic diff=inf, rho=0.228740
# INFO:gensim.models.ldamodel:PROGRESS: pass 18, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:2000/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #42 (0.010): 0.078*"sun" + 0.047*"power" + 0.023*"water" + 0.018*"conte" + 0.017*"electricity" + 0.016*"interest" + 0.015*"jones" + 0.014*"argentine" + 0.014*"life" + 0.013*"600"
# INFO:gensim.models.ldamodel:topic #66 (0.010): 0.035*"posters" + 0.025*"browser" + 0.025*"campaign" + 0.023*"chart" + 0.020*"poster" + 0.018*"ie" + 0.017*"number" + 0.017*"postal" + 0.015*"download" + 0.015*"including"
# INFO:gensim.models.ldamodel:topic #48 (0.010): 0.071*"harry" + 0.041*"potter" + 0.036*"harry_potter" + 0.028*"prisoner" + 0.027*"pull" + 0.021*"2001" + 0.021*"departments" + 0.019*"slimmer" + 0.018*"november" + 0.017*"azkaban"
# INFO:gensim.models.ldamodel:topic #13 (0.010): 0.021*"wage" + 0.019*"country" + 0.019*"minimum" + 0.018*"safer" + 0.017*"issued" + 0.017*"tests" + 0.017*"countries" + 0.015*"working" + 0.015*"we_have" + 0.015*"minimum_wage"
# INFO:gensim.models.ldamodel:topic #7 (0.010): 0.044*"year" + 0.036*"figures" + 0.029*"2004" + 0.024*"sales" + 0.018*"previous" + 0.018*"text" + 0.017*"2005" + 0.016*"total" + 0.015*"billion" + 0.014*"december"
# INFO:gensim.models.ldamodel:topic diff=inf, rho=0.222981
# INFO:gensim.models.ldamodel:PROGRESS: pass 18, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:225/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #61 (0.010): 0.046*"street" + 0.030*"home" + 0.029*"foreign" + 0.028*"straw" + 0.023*"uk" + 0.021*"british" + 0.017*"foreign_secretary" + 0.017*"produced" + 0.016*"mr_straw" + 0.016*"costs"
# INFO:gensim.models.ldamodel:topic #23 (0.010): 0.045*"oil" + 0.032*"yukos" + 0.024*"prices" + 0.020*"ink" + 0.019*"price" + 0.018*"russian" + 0.015*"russia" + 0.014*"woman" + 0.013*"market" + 0.012*"gazprom"
# INFO:gensim.models.ldamodel:topic #69 (0.010): 0.037*"new" + 0.020*"police" + 0.015*"anti" + 0.012*"protection" + 0.011*"measures" + 0.011*"court" + 0.010*"current" + 0.010*"arrested" + 0.009*"rights" + 0.009*"convention"
# INFO:gensim.models.ldamodel:topic #48 (0.010): 0.070*"harry" + 0.045*"potter" + 0.040*"harry_potter" + 0.034*"prisoner" + 0.030*"pull" + 0.025*"slimmer" + 0.023*"2001" + 0.021*"november" + 0.021*"azkaban" + 0.020*"held"
# INFO:gensim.models.ldamodel:topic #47 (0.010): 0.043*"chip" + 0.028*"cell" + 0.021*"intel" + 0.019*"laser" + 0.015*"light" + 0.014*"chips" + 0.014*"data" + 0.012*"silicon" + 0.011*"he_said" + 0.011*"inside"
# INFO:gensim.models.ldamodel:topic diff=inf, rho=0.222981
# INFO:gensim.models.ldamodel:PROGRESS: pass 19, at document #2000/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 2000 documents
# DEBUG:gensim.models.ldamodel:1999/2000 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 2000 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #91 (0.010): 0.032*"game" + 0.020*"  " + 0.019*"fans" + 0.018*"gameplay" + 0.017*"like" + 0.015*"fox" + 0.015*"set" + 0.013*"action" + 0.013*"title" + 0.012*"vast"
# INFO:gensim.models.ldamodel:topic #65 (0.010): 0.016*"fixed" + 0.015*"internet_explorer" + 0.015*"explorer" + 0.013*"home" + 0.013*"critical" + 0.012*"version" + 0.011*"use" + 0.011*"copy" + 0.010*"regular" + 0.010*"is_due"
# INFO:gensim.models.ldamodel:topic #82 (0.010): 0.014*"place" + 0.012*"children" + 0.011*"2002" + 0.011*"tennis" + 0.009*"responsibility" + 0.009*"hope" + 0.009*"men_'s" + 0.009*"going" + 0.009*"failed" + 0.008*"seen"
# INFO:gensim.models.ldamodel:topic #16 (0.010): 0.020*"data" + 0.018*"speed" + 0.018*"high" + 0.017*"year" + 0.016*"more_than" + 0.015*"average" + 0.015*"world" + 0.014*"second" + 0.014*"fast" + 0.013*"speeds"
# INFO:gensim.models.ldamodel:topic #9 (0.010): 0.022*"united" + 0.016*"club" + 0.013*"manchester" + 0.008*"new" + 0.008*"manchester_united" + 0.007*"deal" + 0.007*"john" + 0.007*"singer" + 0.007*"glazer" + 0.006*"city"
# INFO:gensim.models.ldamodel:topic diff=inf, rho=0.217636
# INFO:gensim.models.ldamodel:PROGRESS: pass 19, at document #2225/2225
# DEBUG:gensim.models.ldamodel:performing inference on a chunk of 225 documents
# DEBUG:gensim.models.ldamodel:225/225 documents converged within 100 iterations
# DEBUG:gensim.models.ldamodel:updating topics
# INFO:gensim.models.ldamodel:merging changes from 225 documents into a model of 2225 documents
# INFO:gensim.models.ldamodel:topic #63 (0.010): 0.023*"card" + 0.021*"fraud" + 0.016*"credit" + 0.016*"involved" + 0.015*"people" + 0.013*"internet" + 0.013*"cards" + 0.012*"websites" + 0.012*"crime" + 0.012*"criminals"
# INFO:gensim.models.ldamodel:topic #4 (0.010): 0.023*"growth" + 0.015*"year" + 0.013*"rate" + 0.013*"economy" + 0.011*"rise" + 0.011*"interest" + 0.010*"fall" + 0.009*"bank" + 0.009*"rates" + 0.009*"years"
# INFO:gensim.models.ldamodel:topic #62 (0.010): 0.034*"european" + 0.020*"bill" + 0.019*"europe" + 0.015*"lifts" + 0.012*"developing" + 0.010*"software" + 0.010*"law" + 0.009*"eu" + 0.009*"perspective" + 0.008*"technology"
# INFO:gensim.models.ldamodel:topic #45 (0.010): 0.023*"game" + 0.013*"like" + 0.012*"time" + 0.012*"life" + 0.011*"good" + 0.010*"half" + 0.008*"way" + 0.007*"games" + 0.007*"musicians" + 0.006*"think"
# INFO:gensim.models.ldamodel:topic #21 (0.010): 0.029*"india" + 0.027*"market" + 0.012*"profits" + 0.011*"germany" + 0.011*"lower" + 0.010*"indian" + 0.010*"year" + 0.010*"business" + 0.010*"german" + 0.010*"mobile_operators"
# INFO:gensim.models.ldamodel:topic diff=inf, rho=0.217636
# 100%|██████████| 7/7 [09:03<00:00, 77.67s/it]

# %% [markdown]
# This code gives an impression of how the coherence metric changed for different values of K.

# %%
import pandas as pd

df = pd.DataFrame(history).set_index('K')
_ = df[['uci', 'umass', 'c_v']].plot.line(marker='.', figsize=(12, 12))

# %% [markdown]
# The following code can display as well where the maximum lies for each metric.
#
# In our case, the maximum coherence is obtained:
# * $K = 20$ for $\textrm{C}_V$
# * $K=4$ for UCI
# * $K=6$ for UMass
#
# The choice of the metric and the final decision are out of scope for this class.

# %%
plt.figure(figsize=(12, 12))
plt.title("GridSearch Coherence",
          fontsize=20)

plt.xlabel("K", fontsize=14)
plt.ylabel("Coherence", fontsize=14)

ax = plt.gca()

# Get the regular numpy array from the MaskedArray
X_axis = df.index

scoring = {'UMass': 'umass', 'UCI': 'uci', 'C_V': 'c_v'}

for scorer, color in zip(sorted(scoring), ['tab:blue', 'tab:orange', 'tab:green']):
  sample, style = ('test', '-')
  scores = df[scoring[scorer]]
  ax.plot(X_axis, scores, linestyle=style, color=color, label=scorer, marker='.')

  best_index = scores.idxmax()
  best_score = scores[best_index]

  # Plot a dotted vertical line at the best score for that scorer marked by x
  ax.plot([best_index, ] * 2, [0, best_score],
          linestyle=':', color=color, marker='x', markeredgewidth=3, ms=8, alpha=0.4)

  # Annotate the best score for that scorer
  ax.annotate(f"{best_index:d}",
              (best_index, 0.1), color=color, fontsize=14)

  ax.annotate(f"{best_score:0.2f}",
              (best_index+0.5, best_score + 0.1), color=color, fontsize=14)

plt.legend(loc="best", fontsize=16)
plt.grid(False)
plt.show()

# %% [markdown]
# # LDA with SKLEARN

# %% [markdown]
# Here is an example code on how to use the same data with SKLEARN.
#
# As you can see, we do not obtain exactly the same topics, this is due to the differences in the implementation of the learning algorithm.

# %%
K = 10

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords

stops = stopwords.words('english') + ['said', 'mr']

count = CountVectorizer(
    stop_words=stops,
    ngram_range=(1,2),
    min_df=5,
    max_df=0.9,
)

bow = count.fit_transform(texts)

ldask = LatentDirichletAllocation(
    n_components=K,
    max_iter=100,
    random_state=42)
ldask.fit(bow)
# Out:
# LatentDirichletAllocation(max_iter=100, random_state=42)

# %%
import math
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS

nb_columns = 5
nb_rows = math.ceil(K / nb_columns)

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'
cols = cols * math.ceil(K / len(cols))

cloud = WordCloud(background_color='white',
                  width=400,
                  height=400,
                  max_words=10,
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

# This is different than with GENSIM
topics = ldask.components_
feature_names = count.get_feature_names()
n_top_words = 10
# End Difference

fig, axes = plt.subplots(ncols=nb_columns, nrows=nb_rows,
                         figsize=(4*nb_columns, 4*nb_rows),
                         sharex=True, sharey=True)

for i, (topic, ax) in enumerate(zip(topics, axes.flatten())):
    # This is different than with GENSIM
    top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
    topic_words = {feature_names[i]: topic[i] for i in top_features_ind}
    # End Difference

    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    ax.imshow(cloud)
    ax.set_title(f'Topic {i}', fontdict=dict(size=16))
    ax.axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
from textwrap import fill

topics_in_doc = ldask.transform(bow[:1])

print(f'Document:\n{fill(texts[0])} \n')
print(f'Topics:')
for i, w in enumerate(topics_in_doc[0]):
    print(f'Topic #{i:>2d} : {w:.2f}')
# Out:
# Document:
# musicians to tackle us red tape  musicians' groups are to tackle us
# visa regulations which are blamed for hindering british acts' chances
# of succeeding across the atlantic.  a singer hoping to perform in the
# us can expect to pay $1,300 (£680) simply for obtaining a visa. groups
# including the musicians' union are calling for an end to the "raw
# deal" faced by british performers. us acts are not faced with
# comparable expense and bureaucracy when visiting the uk for
# promotional purposes.  nigel mccune from the musicians' union said
# british musicians are "disadvantaged" compared to their us
# counterparts. a sponsor has to make a petition on their behalf, which
# is a form amounting to nearly 30 pages, while musicians face tougher
# regulations than athletes and journalists. "if you make a mistake on
# your form, you risk a five-year ban and thus the ability to further
# your career," says mr mccune.  "the us is the world's biggest music
# market, which means something has to be done about the creaky
# bureaucracy," says mr mccune. "the current situation is preventing
# british acts from maintaining momentum and developing in the us," he
# added.  the musicians' union stance is being endorsed by the music
# managers' forum (mmf), who say british artists face "an uphill
# struggle" to succeed in the us, thanks to the tough visa requirements,
# which are also seen as impractical. the mmf's general secretary james
# seller said: "imagine if you were an orchestra from the orkneys? every
# member would have to travel to london to have their visas processed."
# "the us market is seen as the holy grail and one of the benchmarks of
# success, and we're still going to fight to get in there. "it's still
# very important, but there are other markets like europe, india and
# china," added mr seller. a department for media, culture and sport
# spokeswoman said: "we're aware that people are experiencing problems,
# and are working with the us embassy and record industry to see what we
# can do about it." a us embassy spokesman said: "we are aware that
# entertainers require visas for time-specific visas and are doing
# everything we can to process those applications speedily." "we are
# aware of the importance of cultural exchange and we will do our best
# to facilitate that," he added.
#
# Topics:
# Topic # 0 : 0.14
# Topic # 1 : 0.12
# Topic # 2 : 0.00
# Topic # 3 : 0.04
# Topic # 4 : 0.26
# Topic # 5 : 0.00
# Topic # 6 : 0.31
# Topic # 7 : 0.00
# Topic # 8 : 0.00
# Topic # 9 : 0.13
