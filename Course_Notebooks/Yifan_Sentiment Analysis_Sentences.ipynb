# %%
# %pip install --upgrade jupyter ipywidgets
# %pip install matplotlib
# %pip install scikit-learn
# %pip install contractions
# %pip install sentence_transformers
# %pip install nltk
# %pip install wordcloud
# %pip install joblib
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# %pip install --upgrade transformers
# %pip install torch torchvision torchaudio
# %pip install seaborn
# %pip install rake_nltk
# Out:
# Requirement already satisfied: jupyter in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: ipywidgets in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (8.1.5)
# Requirement already satisfied: notebook in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter) (7.3.2)
# Requirement already satisfied: jupyter-console in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter) (7.16.5)
# Requirement already satisfied: ipykernel in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: jupyterlab in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter) (4.3.4)
# Requirement already satisfied: comm>=0.1.3 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipywidgets) (8.31.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: exceptiongroup in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: appnope in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipykernel->jupyter) (1.8.11)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: nest-asyncio in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipykernel->jupyter) (24.2)
# Requirement already satisfied: psutil in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipykernel->jupyter) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from ipykernel->jupyter) (6.4.2)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab->jupyter) (3.1.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab->jupyter) (75.8.0)
# Requirement already satisfied: tomli>=1.2.2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.2.1)
# Requirement already satisfied: beautifulsoup4 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nbconvert->jupyter) (3.1.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: anyio in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.8.0)
# Requirement already satisfied: certifi in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.7)
# Requirement already satisfied: idna in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.11.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure_eval in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: sniffio>=1.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: six>=1.5 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: fqdn in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20241206)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: contractions in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from textsearch>=0.0.21->contractions) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sentence_transformers in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from sentence_transformers) (4.48.0)
# Requirement already satisfied: tqdm in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from sentence_transformers) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from sentence_transformers) (1.6.1)
# Requirement already satisfied: scipy in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from sentence_transformers) (1.15.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from sentence_transformers) (0.27.1)
# Requirement already satisfied: Pillow in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from sentence_transformers) (11.1.0)
# Requirement already satisfied: filelock in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (1.13.3)
# Requirement already satisfied: networkx in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.5)
# Requirement already satisfied: numpy>=1.17 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2024.12.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nltk in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nltk) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: wordcloud in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: joblib in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (1.4.2)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: torchvision in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (0.17.2)
# Requirement already satisfied: torchaudio in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: filelock in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: numpy in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (4.48.0)
# Requirement already satisfied: filelock in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from requests->transformers) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: torchvision in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (0.17.2)
# Requirement already satisfied: torchaudio in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: filelock in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: numpy in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting rake_nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from rake_nltk) (3.9.1)
# Requirement already satisfied: click in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (8.1.8)
# Requirement already satisfied: joblib in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /Users/yfd/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (4.67.1)
# Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Installing collected packages: rake_nltk
# Successfully installed rake_nltk-1.0.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import os
from threadpoolctl import threadpool_limits
import contractions

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.decomposition import LatentDirichletAllocation

#from joblib import threadpool_limits

import torch
print(torch.__version__)
from torch import nn
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import re
import string
# Out:
# 2.2.2
# [nltk_data] Downloading package stopwords to /Users/yfd/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Suppress warnings to avoid unnecessary output
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["KMP_DUPLICATE_LIB_OK"] = "True"
os.environ["OMP_NUM_THREADS"] = "1"

# %%
## Load Data

# %%
data = pd.read_pickle("/Users/yfd/Downloads/motley-fool-data.pkl")

# %%
## Filter Data Based on SNP100 List

# %%
# Extract the list of tickers from SNP100
snp100_tickers = SNP100['Symbol'].unique()

# Filter 'data' to include only rows where 'ticker' is in SNP100
filtered_data=data[data['ticker'].isin(snp100_tickers)]

# Save the filtered dataset if needed
filtered_data.to_csv("/Users/yfd/Downloads/filtered_data.csv", index=False)

print(filtered_data.head())

# %%
filtered_data = pd.read_csv("/Users/yfd/Downloads/filtered_data.csv")

# %%
## Extract the speeches from participant in the "call participants"

# %%
# Make a copy of filtered_data to avoid SettingWithCopyWarning
filtered_data = filtered_data.copy()

# Function to extract participants and exclude certain ones
def extract_participants_and_exclude(transcript):
    # Regular expression to capture participants under "Call participants"
    participants_pattern = r"Call participants:\n(.*?)(?=\nMore|\nAll|\Z)"
    
    # Find participants using the pattern
    match = re.search(participants_pattern, transcript, re.DOTALL)
    if match:
        participants_text = match.group(1)
        
        # Split participants into a list
        participants_list = participants_text.strip().split("\n")
        
        # Filter out participants with company names (if more than two parts)
        included_participants = [participant for participant in participants_list if len(participant.split(" -- ")) == 2]
        excluded_participants = [participant for participant in participants_list if len(participant.split(" -- ")) != 2]
        
        return included_participants, excluded_participants
    else:
        return [], []

# Apply the function to the 'transcript' column
filtered_data[['participants', 'excluded_participants']] = filtered_data['transcript'].apply(
    lambda x: pd.Series(extract_participants_and_exclude(x))
)

# %%
def extract_speech(transcript, participants, excluded_participants):
    extracted_speech = {}

    # Define a regex to match any participant's speech until another participant's name or excluded names
    for participant in participants:
        # Build a dynamic regex pattern
        delimiters = participants + excluded_participants + ["Questions and Answers", "Operator"]
        delimiter_pattern = '|'.join([re.escape(d) for d in delimiters])
        pattern = re.compile(rf"({re.escape(participant)})\s*(.*?)(?=\n(?:{delimiter_pattern}|$))", re.DOTALL)
        
        # Find all matches for this participant's speech
        matches = pattern.findall(transcript)
        
        # If matches are found, clean the speech by removing other participants' names
        if matches:
            participant_speech = [match[1].strip() for match in matches]
            for other_participant in participants + excluded_participants:
                if other_participant != participant:
                    participant_speech = [re.sub(rf"\b{re.escape(other_participant)}\b", "", speech) for speech in participant_speech]
            extracted_speech[participant] = participant_speech
        else:
            extracted_speech[participant] = ["No speech found."]
    
    return extracted_speech

# Function to apply extract_speech to each row
def extract_speech_from_df(df):
    df['extracted_speech'] = df.apply(lambda row: extract_speech(row['transcript'], row['participants'], row['excluded_participants']), axis=1)
    return df


# Apply the function to the DataFrame
filtered_data = extract_speech_from_df(filtered_data)

# %%
print(filtered_data.columns)
# Out:
# Index(['date', 'exchange', 'q', 'ticker', 'transcript', 'participants',
#        'excluded_participants', 'extracted_speech'],
#       dtype='object')

# %%
## Display the filtered data

# %%
filtered_data.describe()
# Out:
#                               date      exchange        q ticker  \
# count                         1029          1029     1029   1029
# unique                         668            96       24     96
# top     Jul 22, 2020, 6:00 p.m. ET  NASDAQ: AAPL  2020-Q2   AAPL
# freq                            32            62      111     62
#
#                                                transcript  \
# count                                                1029
# unique                                                779
# top     Prepared Remarks:\nOperator\nLadies and gentle...
# freq                                                   32
#
#                                              participants  \
# count                                                1029
# unique                                                612
# top     [Martin Viecha -- Senior Director for Investor...
# freq                                                   32
#
#                                     excluded_participants  \
# count                                                1029
# unique                                                768
# top     [Dan Levy -- Credit Suisse -- Analyst, Toni Sa...
# freq                                                   32
#
#                                          extracted_speech
# count                                                1029
# unique                                                773
# top     {'Martin Viecha -- Senior Director for Investo...
# freq                                                   32

# %%
## Perform Sentiment Analysis by FineBert Pipeline to Tokenize the Transcripts by Sentences

# %%
from tqdm import tqdm
nltk.download('punkt_tab')
# Initialize the FinBERT sentiment analysis pipeline
finbert_pipeline = pipeline("sentiment-analysis", model="yiyanghkust/finbert-tone", tokenizer="yiyanghkust/finbert-tone")

# Number of rows per batch
batch_size = 100

# Initialize an empty list to store non-neutral sentences
non_neutral_sentences = []

# Define a function to process a batch of unique rows
def process_batch(batch_start, batch_end):
    batch_data = unique_filtered_data.iloc[batch_start:batch_end]  # Slice the unique DataFrame for the current batch

    for index, row in batch_data.iterrows():
        # Get the transcript of the current row
        extracted_speech = row['extracted_speech']  # Dictionary of participants and their transcripts

        # Iterate over each participant and their respective transcript
        for participant, transcript_list in extracted_speech.items():
            # Split the transcript into sentences
            sentences = nltk.sent_tokenize(" ".join(transcript_list))  # Join all the sentences in the list for this participant

            # Run sentiment analysis on each sentence using the FinBERT model
            sentiment_results = finbert_pipeline(sentences)

            # Filter out neutral sentences and save the non-neutral ones
            for i, result in enumerate(sentiment_results):
                if result['label'] != 'neutral':  # Only keep non-neutral sentences
                    non_neutral_sentences.append({
                        'sentence': sentences[i],
                        'label': result['label'],
                        'score': result['score'],
                        'participant': participant,  # Add participant information
                        'ticker': row['ticker']  # Add ticker information
                    })

# Remove duplicate rows based on 'extracted_speech'
unique_filtered_data = filtered_data.drop_duplicates(subset=['extracted_speech'])

# Process the unique data in batches with progress bar
total_rows = len(unique_filtered_data)
with tqdm(total=total_rows, desc="Processing unique batches", unit="row") as pbar:
    for start_row in range(0, total_rows, batch_size):
        end_row = min(start_row + batch_size, total_rows)  # Ensure we don't exceed the DataFrame size
        process_batch(start_row, end_row)  # Process the current batch
        pbar.update(batch_size)  # Update the progress bar

# Convert the list of non-neutral sentences to a DataFrame for easier inspection
non_neutral_sentences_df = pd.DataFrame(non_neutral_sentences)

# Save the results to a CSV file if needed
non_neutral_sentences_df.to_csv("/Users/yfd/Downloads/non_neutral_sentences.csv", index=False)

# Display the first few rows of the non-neutral sentences DataFrame
print(non_neutral_sentences_df.head())

# %%
## Finbert Model to performance sentiment-analysis by person: 100 batch

# %%
## For the sentimental analysis, we did it in colab by gpu then saved the results in the non_neutral_sentences dataset

# %%
sentiment_data = pd.read_csv("/Users/yfd/Downloads/non_neutral_sentences.csv")

# %%
print(sentiment_data.columns)
# Out:
# Index(['sentence', 'label', 'score', 'participant', 'ticker'], dtype='object')

# %%
## Add the q(year_quarter) of sentence in the sentiment_data dataset by merging it with the "Filtered_data" by 'Transcript', 'Sentence' and 'Participants'

# %%
def get_q_from_transcript(sentiment_data, filtered_data):
    q_values = []
    
    # Ensure that columns are strings
    filtered_data['transcript'] = filtered_data['transcript'].astype(str).str.lower().str.strip()
    sentiment_data['sentence'] = sentiment_data['sentence'].astype(str).str.lower().str.strip()
    filtered_data['participants'] = filtered_data['participants'].astype(str).str.lower().str.strip()
    
    # Iterate over each sentence in the sentiment_data dataset
    for index, row in sentiment_data.iterrows():
        participant = row['participant'].strip().lower()
        ticker = row['ticker'].strip().lower()
        sentence = row['sentence']
        
        # Find the matching rows in filtered_data based on 'participant' and 'ticker'
        matching_rows = filtered_data[
            (filtered_data['ticker'].str.lower() == ticker) & 
            (filtered_data['participants'].str.contains(participant))
        ]
        
        # Iterate through the matching rows to find the sentence within the transcript
        found_q = None
        for _, filtered_row in matching_rows.iterrows():
            if sentence in filtered_row['transcript']:  # check for partial match
                found_q = filtered_row['q']
                break
        
        q_values.append(found_q)
    
    # Add the 'q' column to the sentiment_data dataset
    sentiment_data['q'] = q_values
    return sentiment_data

# Example usage
sentences_merged = get_q_from_transcript(sentiment_data, filtered_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 35
#      32     return sentiment_data
#      34 # Example usage
# ---> 35 sentiment_merged = get_q_from_transcript(sentiment_data, filtered_data)
#
# Cell In[45], line 23, in get_q_from_transcript(sentiment_data, filtered_data)
#      21 # Iterate through the matching rows to find the sentence within the transcript
#      22 found_q = None
# ---> 23 for _, filtered_row in matching_rows.iterrows():
#      24     if sentence in filtered_row['transcript']:  # check for partial match
#      25         found_q = filtered_row['q']
#
# File ~/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages/pandas/core/frame.py:1553, in DataFrame.iterrows(self)
#    1551 klass = self._constructor_sliced
#    1552 using_cow = using_copy_on_write()
# -> 1553 for k, v in zip(self.index, self.values):
#    1554     s = klass(v, index=columns, name=k).__finalize__(self)
#    1555     if using_cow and self._mgr.is_single_block:
#
# File ~/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages/pandas/core/frame.py:12664, in DataFrame.values(self)
#   12590 @property
#   12591 def values(self) -> np.ndarray:
#   12592     """
#   12593     Return a Numpy representation of the DataFrame.
#   12594
#    (...)
#   12662            ['monkey', nan, None]], dtype=object)
#   12663     """
# > 12664     return self._mgr.as_array()
#
# File ~/.local/share/mamba/envs/pytorch_env_310/lib/python3.10/site-packages/pandas/core/internals/managers.py:1705, in BlockManager.as_array(self, dtype, copy, na_value)
#    1702 else:
#    1703     arr[isna(arr)] = na_value
# -> 1705 return arr.transpose()
#
# KeyboardInterrupt:

# %%
## Display new merged dataset

# %%
print(sentences_merged)
# Out:
#                                                  sentence     label     score  \
# 0       good morning, ladies and gentlemen, and welcom...   Neutral  0.999439
# 1       on the call with me today are roz brewer, the ...   Neutral  0.999990
# 2       before i hand you over to roz to make some ope...   Neutral  0.997839
# 3       certain statements and projections of future r...   Neutral  0.980985
# 4       we undertake no obligation to update publicly ...   Neutral  0.998404
# ...                                                   ...       ...       ...
# 319372  we're building nvidia ai and nvidia omniverse ...  Positive  0.995862
# 319373  i look forward to next month's gtc conference,...  Positive  0.999911
# 319374                                        so join us.   Neutral  0.997636
# 319375  we look forward to updating you on our progres...   Neutral  0.999664
# 319376                                         thank you.   Neutral  0.830430
#
#                                               participant ticker        q
# 0       Gerald Gradwell -- Senior Vice President of In...    WBA  2021-Q3
# 1       Gerald Gradwell -- Senior Vice President of In...    WBA  2021-Q3
# 2       Gerald Gradwell -- Senior Vice President of In...    WBA  2021-Q3
# 3       Gerald Gradwell -- Senior Vice President of In...    WBA  2021-Q3
# 4       Gerald Gradwell -- Senior Vice President of In...    WBA  2021-Q3
# ...                                                   ...    ...      ...
# 319372  Jensen Huang -- President and Chief Executive ...   NVDA  2023-Q2
# 319373  Jensen Huang -- President and Chief Executive ...   NVDA  2023-Q2
# 319374  Jensen Huang -- President and Chief Executive ...   NVDA  2023-Q2
# 319375  Jensen Huang -- President and Chief Executive ...   NVDA  2020-Q2
# 319376  Jensen Huang -- President and Chief Executive ...   NVDA  2020-Q2
#
# [319377 rows x 6 columns]

# %%
sentences_merged.to_csv("/Users/yfd/Downloads/sentences_merged.csv", index=False)

# %%
sentiment_merged = pd.read_csv("/Users/yfd/Downloads/sentences_merged.csv")

# %%
sentiment_merged
# Out:
#                                                  sentence     label     score  \
# 0       good morning, ladies and gentlemen, and welcom...   Neutral  0.999439
# 1       on the call with me today are roz brewer, the ...   Neutral  0.999990
# 2       before i hand you over to roz to make some ope...   Neutral  0.997839
# 3       certain statements and projections of future r...   Neutral  0.980985
# 4       we undertake no obligation to update publicly ...   Neutral  0.998404
# ...                                                   ...       ...       ...
# 319372  we're building nvidia ai and nvidia omniverse ...  Positive  0.995862
# 319373  i look forward to next month's gtc conference,...  Positive  0.999911
# 319374                                        so join us.   Neutral  0.997636
# 319375  we look forward to updating you on our progres...   Neutral  0.999664
# 319376                                         thank you.   Neutral  0.830430
#
#                                               participant ticker        q
# 0       Gerald Gradwell -- Senior Vice President of In...    WBA  2021-Q3
# 1       Gerald Gradwell -- Senior Vice President of In...    WBA  2021-Q3
# 2       Gerald Gradwell -- Senior Vice President of In...    WBA  2021-Q3
# 3       Gerald Gradwell -- Senior Vice President of In...    WBA  2021-Q3
# 4       Gerald Gradwell -- Senior Vice President of In...    WBA  2021-Q3
# ...                                                   ...    ...      ...
# 319372  Jensen Huang -- President and Chief Executive ...   NVDA  2023-Q2
# 319373  Jensen Huang -- President and Chief Executive ...   NVDA  2023-Q2
# 319374  Jensen Huang -- President and Chief Executive ...   NVDA  2023-Q2
# 319375  Jensen Huang -- President and Chief Executive ...   NVDA  2020-Q2
# 319376  Jensen Huang -- President and Chief Executive ...   NVDA  2020-Q2
#
# [319377 rows x 6 columns]

# %%
## Display the top 10 negative sentences by each transcript and show its 'speaker name' and 'speak title' and 'score' and 'label'

# %%
import pandas as pd

def split_participant_and_process_title(sentiment_merged):
    # Split the 'participant' column into 'speaker name' and 'speaker title'
    sentiment_merged[['speaker name', 'speaker title']] = sentiment_merged['participant'].str.split(' -- ', expand=True)

    # Simplify the speaker title based on conditions
    sentiment_merged['speaker title'] = sentiment_merged['speaker title'].apply(
        lambda title: 'CEO' if 'Chief Executive Officer' in title else 
                      ('CFO' if 'Chief Financial Officer' in title else 'Else')
    )
    
    return sentiment_merged

def get_top_negative_sentences(sentiment_merged):
    # Apply the function to split 'participant' and process the title
    sentiment_merged = split_participant_and_process_title(sentiment_merged)

    # Create a new combined column 'ticker_q' that combines 'ticker' and 'q'
    sentiment_merged['ticker_q'] = sentiment_merged['ticker'] + '_' + sentiment_merged['q'].astype(str)

    # Create an empty list to store the results
    top_negative_sentences = []

    # Group by the combined column 'ticker_q'
    for ticker_q, group in sentiment_merged.groupby('ticker_q'):
        # Filter only negative sentences and sort them by 'score' in descending order
        negative_sentences = group[group['label'] == 'Negative'].sort_values(by='score', ascending=False).head(10)

        # Append top 5 negative sentences
        for _, row in negative_sentences.iterrows():
            top_negative_sentences.append({
                'label': row['label'],
                'score': row['score'],
                'speaker name': row['speaker name'],
                'speaker title': row['speaker title'],
                'q': row['q'],
                'ticker': row['ticker'],
                'sentiment': 'Negative',
                'sentence': row['sentence']
            })

    # Create a DataFrame from the top negative sentences list
    top_negative_sentences_df = pd.DataFrame(top_negative_sentences)
    return top_negative_sentences_df

# Example usage
top_negative_sentences = get_top_negative_sentences(sentiment_merged)

# Show the first few rows of the top_negative_sentences DataFrame
top_negative_sentences.head()
# Out:
#       label     score  speaker name speaker title        q ticker sentiment  \
# 0  Negative  1.000000  Luca Maestri           CFO  2019-Q3   AAPL  Negative
# 1  Negative  1.000000  Luca Maestri           CFO  2019-Q3   AAPL  Negative
# 2  Negative  0.999980  Luca Maestri           CFO  2019-Q3   AAPL  Negative
# 3  Negative  0.999923      Tim Cook           CEO  2019-Q3   AAPL  Negative
# 4  Negative  0.999911  Luca Maestri           CFO  2019-Q3   AAPL  Negative
#
#                                             sentence
# 0  products gross margin was 30.4%, down about 80...
# 1  iphone revenue was $26 billion, down 12% compa...
# 2  on the negative side, the headwind on gross ma...
# 3  and i apologize for my voice, i'm suffering fr...
# 4  this guidance includes almost $1 billion of th...

# %%
top_negative_sentences['sentence']
# Out:
# 0       products gross margin was 30.4%, down about 80...
# 1       iphone revenue was $26 billion, down 12% compa...
# 2       on the negative side, the headwind on gross ma...
# 3       and i apologize for my voice, i'm suffering fr...
# 4       this guidance includes almost $1 billion of th...
#                               ...
# 7560    and, obviously, it's challenged in the chemica...
# 7561    it's -- i think you hit on a very good point, ...
# 7562    and so, like a lot of the parts of our busines...
# 7563    and price timing impacts, and again, i would h...
# 7564    and instead, what's been put in place is a pen...
# Name: sentence, Length: 7565, dtype: object

# %%
## Show the number and percentage of sentences by title

# %%
def count_negative_sentences_by_title(sentiment_merged):
   
    # Count the number of negative sentences per title
    counts = top_negative_sentences['speaker title'].value_counts()

    # Calculate the percentage of negative sentences per title
    percentages = (counts / counts.sum()) * 100

    # Combine counts and percentages into a single DataFrame
    summary_df = pd.DataFrame({
        'title': counts.index,
        'count': counts.values,
        'percentage': percentages.values
    })

    return summary_df

# Example usage
negative_summary = count_negative_sentences_by_title(sentiment_merged)

# Display the results
negative_summary
# Out:
#   title  count  percentage
# 0   CFO   4212   55.677462
# 1   CEO   2307   30.495704
# 2  Else   1046   13.826834

# %%
## Filter the over-negative sentences with score 1

# %%
def filter_negative_score_one(sentiment_merged):
    # Apply the function to split 'participant' and process the title
    sentiment_merged = split_participant_and_process_title(sentiment_merged)

    # Filter rows where label is 'Negative' and score equals 1
    negative_score_one = sentiment_merged[
        (sentiment_merged['label'] == 'Negative') & (sentiment_merged['score'] == 1)
    ]

    return negative_score_one

# Example usage
negative_score_one_df = filter_negative_score_one(sentiment_merged)

# Display the filtered sentences
negative_score_one_df[['sentence', 'label', 'score', 'speaker name', 'speaker title', 'ticker', 'q']]
# Out:
#                                                  sentence     label  score  \
# 4704    this was below our expectations due to the sof...  Negative    1.0
# 14949   ipad revenue was $7.2 billion, down 2% year ov...  Negative    1.0
# 20857   revenue was $15.3 billion, 15% below our origi...  Negative    1.0
# 20869   dcai revenue was $4.6 billion, below expectati...  Negative    1.0
# 20931   and maybe i'll just add, in terms of profitabi...  Negative    1.0
# 44490   these results came in below the guidance we ga...  Negative    1.0
# 50313   now there were parts of the quarter that playe...  Negative    1.0
# 50320   the shortfall to our revenue guidance was prim...  Negative    1.0
# 50326   and this resulted in large back orders and cau...  Negative    1.0
# 50631   our fourth quarter organic revenue increased 1...  Negative    1.0
# 69427   gross margin pressure led to a decline in oper...  Negative    1.0
# 76979   the bottom line was below our expectations due...  Negative    1.0
# 77218   gross margin pressure and expense deleverage l...  Negative    1.0
# 85738   last year, as we discussed with you, we identi...  Negative    1.0
# 91249   this was due to continued volume pressure and ...  Negative    1.0
# 106327  psg revenue was $486 million, down 3% year ove...  Negative    1.0
# 110242  in summary, our results in the second quarter ...  Negative    1.0
# 143361  the new forecast reflects our lowered revenue ...  Negative    1.0
# 143367  a new forecast also reflects the loss of fedex...  Negative    1.0
# 161637  at fedex express we expect earnings to be down...  Negative    1.0
# 170189  we've delivered 189 airplanes year to date, be...  Negative    1.0
# 175056  our first quarter gross margin rate was well b...  Negative    1.0
# 175221  this was driven by a number of factors, the mo...  Negative    1.0
# 191348  we felt the short-term impacts of omicron in j...  Negative    1.0
# 204024  there are two main factors that are driving th...  Negative    1.0
# 210114  devices revenue decreased 39% to 34% in consta...  Negative    1.0
# 212628  the performance was below our and consensus ex...  Negative    1.0
# 223089  but our top line results were pressured by two...  Negative    1.0
# 231540  q3 revenue was $18.1 billion, slightly below o...  Negative    1.0
# 244661  revenue at fedex express was down 6% year over...  Negative    1.0
# 244832  how i would address that is, as you saw in the...  Negative    1.0
# 250285  ipad revenue was $7.6 billion, down 2% year ov...  Negative    1.0
# 258253  the impact of constrained labor markets remain...  Negative    1.0
# 258892  operating profit was $17 million, below expect...  Negative    1.0
# 261649  revenue came in at 543 million below our guida...  Negative    1.0
# 264008  the pipeline outage on epng, the freeport lng ...  Negative    1.0
# 264276  global xeljanz' revenue were down 9% operation...  Negative    1.0
# 269944  imbruvica global revenues were approximately $...  Negative    1.0
# 272609  the second factor was a modestly worse economi...  Negative    1.0
# 293585  service revenue was $3.4 billion, down 1%, dri...  Negative    1.0
# 296665  the slower-than-expected growth was due to rap...  Negative    1.0
# 303310  this was slightly below our expectations as ba...  Negative    1.0
# 308680  as expected, rf front-end revenues of $992 mil...  Negative    1.0
# 319019  as we had indicated in our pre-announcement pr...  Negative    1.0
#
#                  speaker name speaker title ticker        q
# 4704             Brian Newman           CFO    UPS  2021-Q4
# 14949            Luca Maestri           CFO   AAPL  2022-Q3
# 20857           David Zinsner           CFO   INTC  2022-Q2
# 20869           David Zinsner           CFO   INTC  2022-Q2
# 20931           David Zinsner           CFO   INTC  2022-Q2
# 44490      Christine McCarthy           CFO    DIS  2023-Q1
# 50313            Geoff Martha           CEO    MDT  2022-Q4
# 50320            Geoff Martha           CEO    MDT  2022-Q4
# 50326            Geoff Martha           CEO    MDT  2022-Q4
# 50631          Karen Parkhill           CFO    MDT  2022-Q4
# 69427       John David Rainey           CFO    WMT  2023-Q2
# 76979           Doug McMillon           CEO    WMT  2023-Q1
# 77218             Brett Biggs           CFO    WMT  2023-Q1
# 85738         James D. Farley          Else      F  2018-Q4
# 91249   Carolina Dybeck Happe           CFO     GE  2020-Q4
# 106327           George Davis           CFO   INTC  2021-Q2
# 110242       John Shrewsberry           CFO    WFC  2020-Q2
# 143361           Alan B. Graf           CFO    FDX  2020-Q1
# 143367           Alan B. Graf           CFO    FDX  2020-Q1
# 161637           Alan B. Graf           CFO    FDX  2019-Q4
# 170189             Brian West           CFO     BA  2022-Q2
# 175056          Brian Cornell           CEO    TGT  2022-Q1
# 175221   Christina Hennington          Else    TGT  2022-Q1
# 191348           Geoff Martha           CEO    MDT  2022-Q3
# 204024       Pascal Desroches           CFO      T  2022-Q2
# 210114               Amy Hood           CFO   MSFT  2023-Q2
# 212628         David Risinger          Else    PFE  2022-Q2
# 223089             Larry Culp           CEO     GE  2021-Q4
# 231540           George Davis           CFO   INTC  2021-Q3
# 244661            Brie Carere          Else    FDX  2023-Q2
# 244832              Mike Lenz           CFO    FDX  2023-Q2
# 250285           Luca Maestri           CFO   AAPL  2022-Q2
# 258253        Raj Subramaniam          Else    FDX  2022-Q1
# 258892           Dave Zinsner           CFO   INTC  2022-Q3
# 261649        Phebe Novakovic           CEO     GD  2021-Q4
# 264008               Kim Dang          Else    KMI  2022-Q3
# 264276          Albert Bourla           CEO    PFE  2021-Q2
# 269944           Jeff Stewart          Else   ABBV  2022-Q2
# 272609           Andrew Young           CFO    COF  2022-Q4
# 293585           Scott Herren           CFO   CSCO  2022-Q2
# 296665             Mike Roman           CEO    MMM  2022-Q4
# 303310           Dan Schulman           CEO   PYPL  2021-Q3
# 308680       Akash Palkhiwala           CFO   QCOM  2022-Q4
# 319019          Colette Kress           CFO   NVDA  2023-Q2

# %%
# Display the filtered sentences
negative_score_one_df[['sentence','speaker title', 'ticker', 'q']]
# Out:
#                                                  sentence speaker title  \
# 4704    this was below our expectations due to the sof...           CFO
# 14949   ipad revenue was $7.2 billion, down 2% year ov...           CFO
# 20857   revenue was $15.3 billion, 15% below our origi...           CFO
# 20869   dcai revenue was $4.6 billion, below expectati...           CFO
# 20931   and maybe i'll just add, in terms of profitabi...           CFO
# 44490   these results came in below the guidance we ga...           CFO
# 50313   now there were parts of the quarter that playe...           CEO
# 50320   the shortfall to our revenue guidance was prim...           CEO
# 50326   and this resulted in large back orders and cau...           CEO
# 50631   our fourth quarter organic revenue increased 1...           CFO
# 69427   gross margin pressure led to a decline in oper...           CFO
# 76979   the bottom line was below our expectations due...           CEO
# 77218   gross margin pressure and expense deleverage l...           CFO
# 85738   last year, as we discussed with you, we identi...          Else
# 91249   this was due to continued volume pressure and ...           CFO
# 106327  psg revenue was $486 million, down 3% year ove...           CFO
# 110242  in summary, our results in the second quarter ...           CFO
# 143361  the new forecast reflects our lowered revenue ...           CFO
# 143367  a new forecast also reflects the loss of fedex...           CFO
# 161637  at fedex express we expect earnings to be down...           CFO
# 170189  we've delivered 189 airplanes year to date, be...           CFO
# 175056  our first quarter gross margin rate was well b...           CEO
# 175221  this was driven by a number of factors, the mo...          Else
# 191348  we felt the short-term impacts of omicron in j...           CEO
# 204024  there are two main factors that are driving th...           CFO
# 210114  devices revenue decreased 39% to 34% in consta...           CFO
# 212628  the performance was below our and consensus ex...          Else
# 223089  but our top line results were pressured by two...           CEO
# 231540  q3 revenue was $18.1 billion, slightly below o...           CFO
# 244661  revenue at fedex express was down 6% year over...          Else
# 244832  how i would address that is, as you saw in the...           CFO
# 250285  ipad revenue was $7.6 billion, down 2% year ov...           CFO
# 258253  the impact of constrained labor markets remain...          Else
# 258892  operating profit was $17 million, below expect...           CFO
# 261649  revenue came in at 543 million below our guida...           CEO
# 264008  the pipeline outage on epng, the freeport lng ...          Else
# 264276  global xeljanz' revenue were down 9% operation...           CEO
# 269944  imbruvica global revenues were approximately $...          Else
# 272609  the second factor was a modestly worse economi...           CFO
# 293585  service revenue was $3.4 billion, down 1%, dri...           CFO
# 296665  the slower-than-expected growth was due to rap...           CEO
# 303310  this was slightly below our expectations as ba...           CEO
# 308680  as expected, rf front-end revenues of $992 mil...           CFO
# 319019  as we had indicated in our pre-announcement pr...           CFO
#
#        ticker        q
# 4704      UPS  2021-Q4
# 14949    AAPL  2022-Q3
# 20857    INTC  2022-Q2
# 20869    INTC  2022-Q2
# 20931    INTC  2022-Q2
# 44490     DIS  2023-Q1
# 50313     MDT  2022-Q4
# 50320     MDT  2022-Q4
# 50326     MDT  2022-Q4
# 50631     MDT  2022-Q4
# 69427     WMT  2023-Q2
# 76979     WMT  2023-Q1
# 77218     WMT  2023-Q1
# 85738       F  2018-Q4
# 91249      GE  2020-Q4
# 106327   INTC  2021-Q2
# 110242    WFC  2020-Q2
# 143361    FDX  2020-Q1
# 143367    FDX  2020-Q1
# 161637    FDX  2019-Q4
# 170189     BA  2022-Q2
# 175056    TGT  2022-Q1
# 175221    TGT  2022-Q1
# 191348    MDT  2022-Q3
# 204024      T  2022-Q2
# 210114   MSFT  2023-Q2
# 212628    PFE  2022-Q2
# 223089     GE  2021-Q4
# 231540   INTC  2021-Q3
# 244661    FDX  2023-Q2
# 244832    FDX  2023-Q2
# 250285   AAPL  2022-Q2
# 258253    FDX  2022-Q1
# 258892   INTC  2022-Q3
# 261649     GD  2021-Q4
# 264008    KMI  2022-Q3
# 264276    PFE  2021-Q2
# 269944   ABBV  2022-Q2
# 272609    COF  2022-Q4
# 293585   CSCO  2022-Q2
# 296665    MMM  2022-Q4
# 303310   PYPL  2021-Q3
# 308680   QCOM  2022-Q4
# 319019   NVDA  2023-Q2
